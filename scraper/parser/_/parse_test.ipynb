# %%
from awpy.parser import DemoParser as Parser

asd = Parser(demofile='../demo/matches/2023/blast-premier-fall-groups-2023-astralis-vs-complexity-bo3-rg1q7_uJ_qZs1xTVhaJobF/astralis-vs-complexity-m1-vertigo.dem', demo_id='asd', parse_rate=128)
asd.parse(return_type='df')
# Out:
# {'matchID': 'asd',
#  'clientName': 'GOTV Demo',
#  'mapName': 'de_vertigo',
#  'tickRate': 128,
#  'playbackTicks': 492371,
#  'rounds':     roundNum matchID     mapName  startTick  freezeTimeEndTick  endTick  \
#  0          1     asd  de_vertigo       1193              21519    26977
#  1          2     asd  de_vertigo      27617              30177    35977
#  2          3     asd  de_vertigo      36617              39177    50058
#  3          4     asd  de_vertigo      50698              53258    68230
#  4          5     asd  de_vertigo      68870              71430    86610
#  5          6     asd  de_vertigo      87250              89810   102449
#  6          7     asd  de_vertigo     103089             105649   120369
#  7          8     asd  de_vertigo     121009             127409   135861
#  8          9     asd  de_vertigo     136501             139061   154833
#  9         10     asd  de_vertigo     155473             163023   175706
# ...
