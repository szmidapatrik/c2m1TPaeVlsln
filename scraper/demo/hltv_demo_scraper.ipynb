# %% [markdown]
# # Creation of the scraper
# Functions which complete parts of the demo scraping.
# *   1. Function: Gets the download link for the demo files for each match of a tournament.
# *   2. Function: Downloads the demo files's rar containers.
# *   3. Function: Counts the rar files in the given folder, thus allowing the 2. Function to check wether the download is completed.
# *   4. Function: Unzips the downloaded rars, which contain the demo files for each match.

# %% [markdown]
# ## Get the links to the given Tournament's matches
# Function that expects one parameter:
# *   *link*, a Tournament's results link from HLTV,
#
#  from which it collects the links of the demo files' download page, and returns them in a string array.
#
#  An example link: *https://www.hltv.org/results?content=demo&event=6809*

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from time import sleep
import random


def get_tournament_demo_links(link):
    
    # Allow cookies
    browser = webdriver.Chrome()
    # Remove navigator.webdriver Flag using JavaScript
    browser.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")
    browser.get(link)
    allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
    sleep(random.uniform(0.8, 2.8))
    allowCookies.click()
    sleep(2)

    # Get the match list items
    matches = browser.find_elements(By.CLASS_NAME, 'result-con')
    matchLinks = []
    for match in matches:
        matchLinks.append(match.find_element(By.CLASS_NAME, 'a-reset').get_attribute('href'))

    # Finish and quit browser, return links
    browser.quit()
    return matchLinks

# %% [markdown]
# ## Function to count files in a given folder
# This function expects two parameters:
# * *fileType* determines the sought file type
# * *folderPath* defines in which folder the function will search for the given file extension
#
# In this scenario, it is used to detect  wether the number of rar files changed, allowing us the check if the current demo file's dowload is complete

# %%
import os

def get_file_count(fileType, folderPath):

    fileExtensionList = []

    # Iterate directory
    for filename in os.listdir(folderPath):
        f = os.path.join(folderPath, filename)
        # Checking files and counting rars 
        if os.path.isfile(f):
            if '.' not in filename:
                continue
            fileExtensionList.append(filename.rsplit('.', 1)[1])
    
    fileCount = 0
    for file in fileExtensionList:
        if file == fileType:
            fileCount += 1
    
    return fileCount

# %% [markdown]
# ## Download all matches' demos for the given Tourament
# The function expects two parameters:
# *   *tournament*, which must contain the **get_tournament_demo_links** function's returned links,
# *   *downloadPath*, which determines where the demo files will be dowloaded.
#
# This method runs through all the collected links of the gven tournament's matches, and downloads the demo files from it.
# Tested with download path: r"D:\bme\MSc\csgo\data-scape\awpy\demo\download"

# %%
def download_demos(tournament, downloadPath):
    # Set download path
    chromeOptions = webdriver.ChromeOptions()
    prefs = {"download.default_directory" : downloadPath}
    chromeOptions.add_experimental_option("prefs",prefs)

    # Iterate through the matches' links
    for matchLink in tournament:

        # Start browser, allow cookies
        browser = webdriver.ChromiumEdge(options=chromeOptions)
        # Remove navigator.webdriver Flag using JavaScript
        browser.execute_script("Object.defineProperty(navigator, 'webdriver', {get: () => undefined})")
        browser.get(matchLink)
        allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
        sleep(random.uniform(0.8, 2.8))
        allowCookies.click()
        sleep(random.uniform(1, 1.9))

        # Find download button
        downloadLink = browser.find_element(By.CLASS_NAME, 'stream-box').get_attribute('data-demo-link')

        # Start download and wait while completed
        rarCountBeforeDownload = get_file_count('rar', downloadPath)
        browser.get('https://www.hltv.org' + downloadLink)
        while get_file_count('rar', downloadPath) == rarCountBeforeDownload:
            sleep(5)

        # Quit browser
        browser.quit()

# %% [markdown]
# ## Function to unzip the demo files
# Function that expects two parameters:
# *   *sourceFolder*, which determines the rar files' source folder,
# *   *destFolder*, the destination folder of the unzipping procedure.
#
# This function iterates throught the given *sourceFolder*, unzips all the rar files and gets all the demos from them.

# %%
import patoolib
import os

def unzip_demo_files(sourceFolder, destFolder):

    # Iterate directory
    for filename in os.listdir(sourceFolder):
        filename = os.path.join(sourceFolder, filename)
        if 'sync' in filename:
            os.remove(filename)
            continue
        patoolib.extract_archive(filename, outdir=destFolder)

# %% [markdown]
# # All-in-one function
# The combination of the previously created functions. In this section, the user can download and unpack whole Counter Strike tournaments' demo files using the *demo_downloader* funcion. It expects two parameters:
# *   *link*: The HTML link of the tournament the user wishes to download. An example link: https://www.hltv.org/results?content=demo&event=6809
# *   *path*: Both the download and unpack path.

# %% [markdown]
# ##### Function implementation

# %%
def demo_downloader_for_tournaments(link, path):
    download_demos(get_tournament_demo_links(link), path + '/source')
    # unzip_demo_files(path + '\source', path)

# %% [markdown]
# ##### Sandbox

# %%
demo_downloader_for_tournaments('https://www.hltv.org/results?event=6140', r'/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo')

# %% [markdown]
# # Module

# %%
import pandas as pd
import numpy as np
import random
import sys
import os

pd.set_option('display.max_columns', 100)
sys.path.append(os.path.abspath('./hltv-demo-scraper'))

from hltv_demo_scraper import HLTV_Demo_Scraper

# %%
HLTV_Demo_Scraper().demo_downloader_for_tournaments('https://www.hltv.org/results?event=7485', r'E:\csgo-gnn\data\matches-raw\cs2\2023\zip', r'E:\csgo-gnn\data\matches-raw\cs2\2023')

# %%
HLTV_Demo_Scraper().unzip_demo_files('../../data/matches-raw/cs2/2023/zip', '../../data/matches-raw/cs2/2023')
# Out:
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-aurora-vs-mibr-bo3-WTc3uEVsZDra2_gdtosbfG.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-aurora-vs-mibr-bo3-WTc3uEVsZDra2_gdtosbfG.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-aurora-vs-mibr-bo3-WTc3uEVsZDra2_gdtosbfG.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-betboom-vs-falcons-bo3-Vs2aqVHybmmMIUkgtc2WlF.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-betboom-vs-falcons-bo3-Vs2aqVHybmmMIUkgtc2WlF.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-betboom-vs-falcons-bo3-Vs2aqVHybmmMIUkgtc2WlF.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-falcons-vs-virtuspro-bo3-PK5wVMNEEkNbm0asV_y_g0.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-falcons-vs-virtuspro-bo3-PK5wVMNEEkNbm0asV_y_g0.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-falcons-vs-virtuspro-bo3-PK5wVMNEEkNbm0asV_y_g0.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-0yMXVWNlUA3AGShijb94ae.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-0yMXVWNlUA3AGShijb94ae.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-0yMXVWNlUA3AGShijb94ae.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-Xf2LBT-kpXCocwXL5a1T95.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-Xf2LBT-kpXCocwXL5a1T95.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-heroic-vs-mibr-bo3-Xf2LBT-kpXCocwXL5a1T95.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-betboom-bo3-m42NJNG8QaPyV3laoD--c_.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-betboom-bo3-m42NJNG8QaPyV3laoD--c_.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-betboom-bo3-m42NJNG8QaPyV3laoD--c_.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-heroic-bo3-mSiQED1Q0M_KYoupeEXzlx.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-heroic-bo3-mSiQED1Q0M_KYoupeEXzlx.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-heroic-bo3-mSiQED1Q0M_KYoupeEXzlx.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-virtuspro-bo3-rtRcrN6AfNrJ3Hnw732WuF.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-virtuspro-bo3-rtRcrN6AfNrJ3Hnw732WuF.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-mouz-vs-virtuspro-bo3-rtRcrN6AfNrJ3Hnw732WuF.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-aurora-bo3-DocgEwWrnHDoWY2Qi13NA6.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-aurora-bo3-DocgEwWrnHDoWY2Qi13NA6.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-aurora-bo3-DocgEwWrnHDoWY2Qi13NA6.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-falcons-bo3-m-Cq402j5ScOtFCK65s-cs.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-falcons-bo3-m-Cq402j5ScOtFCK65s-cs.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-falcons-bo3-m-Cq402j5ScOtFCK65s-cs.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-heroic-bo3-5DMxU6BGEdsQdnOx1oKcGP.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-heroic-bo3-5DMxU6BGEdsQdnOx1oKcGP.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-heroic-bo3-5DMxU6BGEdsQdnOx1oKcGP.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-mouz-bo5-sUtWGNraDW82JYvsyUIGyF.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-mouz-bo5-sUtWGNraDW82JYvsyUIGyF.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-spirit-vs-mouz-bo5-sUtWGNraDW82JYvsyUIGyF.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-virtuspro-vs-falcons-bo3-3B5KOpfo1qguVHHPlFVSSA.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-virtuspro-vs-falcons-bo3-3B5KOpfo1qguVHHPlFVSSA.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\betboom-dacha-belgrade-2024-virtuspro-vs-falcons-bo3-3B5KOpfo1qguVHHPlFVSSA.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-heroic-bo3-FZhx5bice3pWss26wFHIIY.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-heroic-bo3-FZhx5bice3pWss26wFHIIY.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-heroic-bo3-FZhx5bice3pWss26wFHIIY.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-natus-vincere-bo3-vxKYiMWUPLiYn9oyBq6Njd.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-natus-vincere-bo3-vxKYiMWUPLiYn9oyBq6Njd.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-cloud9-vs-natus-vincere-bo3-vxKYiMWUPLiYn9oyBq6Njd.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-complexity-vs-astralis-bo3-LNsHrZTARQ9YSlpIxOBAn2.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-complexity-vs-astralis-bo3-LNsHrZTARQ9YSlpIxOBAn2.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-complexity-vs-astralis-bo3-LNsHrZTARQ9YSlpIxOBAn2.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-cloud9-bo3-3ECN30RCcX19MlizvjfxZ8.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-cloud9-bo3-3ECN30RCcX19MlizvjfxZ8.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-cloud9-bo3-3ECN30RCcX19MlizvjfxZ8.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-complexity-bo3-N67TzhZoppYELV0X6voA50.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-complexity-bo3-N67TzhZoppYELV0X6voA50.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-complexity-bo3-N67TzhZoppYELV0X6voA50.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-ninjas-in-pyjamas-bo3-wo3NIa9YQZnpyYTg01pytb.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-ninjas-in-pyjamas-bo3-wo3NIa9YQZnpyYTg01pytb.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-faze-vs-ninjas-in-pyjamas-bo3-wo3NIa9YQZnpyYTg01pytb.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-heroic-vs-astralis-bo3-3LCArRY20rFMRjYYSF35_x.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-heroic-vs-astralis-bo3-3LCArRY20rFMRjYYSF35_x.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-heroic-vs-astralis-bo3-3LCArRY20rFMRjYYSF35_x.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-natus-vincere-vs-complexity-bo3-tQ0gtzMZQGREdormUTBh2T.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-natus-vincere-vs-complexity-bo3-tQ0gtzMZQGREdormUTBh2T.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-natus-vincere-vs-complexity-bo3-tQ0gtzMZQGREdormUTBh2T.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-ninjas-in-pyjamas-vs-natus-vincere-bo3-fa-fyPRazVwoO34DwnYayx.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-ninjas-in-pyjamas-vs-natus-vincere-bo3-fa-fyPRazVwoO34DwnYayx.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-ninjas-in-pyjamas-vs-natus-vincere-bo3-fa-fyPRazVwoO34DwnYayx.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-cloud9-bo3-zUIRb7v6M6zsMG7pZgHbMi.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-cloud9-bo3-zUIRb7v6M6zsMG7pZgHbMi.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-cloud9-bo3-zUIRb7v6M6zsMG7pZgHbMi.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-complexity-bo3-G-ZaUjuZ52TPMUhj947hGq.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-complexity-bo3-G-ZaUjuZ52TPMUhj947hGq.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-complexity-bo3-G-ZaUjuZ52TPMUhj947hGq.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-faze-bo3-BvVF-LGwD8SDXSrEqMqtUa.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-faze-bo3-BvVF-LGwD8SDXSrEqMqtUa.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-faze-bo3-BvVF-LGwD8SDXSrEqMqtUa.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-heroic-bo3-9zNsp9vKgCG5KpvZtTZn8y.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-heroic-bo3-9zNsp9vKgCG5KpvZtTZn8y.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-fall-final-2023-vitality-vs-heroic-bo3-9zNsp9vKgCG5KpvZtTZn8y.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-astralis-vs-virtuspro-bo3-MPKVFectLYZpY_brKJhH1s.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-astralis-vs-virtuspro-bo3-MPKVFectLYZpY_brKJhH1s.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-astralis-vs-virtuspro-bo3-MPKVFectLYZpY_brKJhH1s.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-natus-vincere-bo3-lAsKc25bIGRQM6cjTQTgIu.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-natus-vincere-bo3-lAsKc25bIGRQM6cjTQTgIu.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-natus-vincere-bo3-lAsKc25bIGRQM6cjTQTgIu.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-saw-bo3-ESSTYxFkvaG2Ij-q_tbYfk.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-saw-bo3-ESSTYxFkvaG2Ij-q_tbYfk.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-saw-bo3-ESSTYxFkvaG2Ij-q_tbYfk.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-vitality-bo3-lQLvdLlJcL7dI4fNDLSZOX.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-vitality-bo3-lQLvdLlJcL7dI4fNDLSZOX.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-faze-vs-vitality-bo3-lQLvdLlJcL7dI4fNDLSZOX.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-astralis-bo3-o0PMf3uM9V74BSNEQZZzF4.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-astralis-bo3-o0PMf3uM9V74BSNEQZZzF4.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-astralis-bo3-o0PMf3uM9V74BSNEQZZzF4.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-virtuspro-bo3-_jN2p4QLiCaUWywo3wBO-X.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-virtuspro-bo3-_jN2p4QLiCaUWywo3wBO-X.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-natus-vincere-vs-virtuspro-bo3-_jN2p4QLiCaUWywo3wBO-X.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-saw-vs-astralis-bo3-CVFySu5vH0SDxuYWfQA4dZ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-saw-vs-astralis-bo3-CVFySu5vH0SDxuYWfQA4dZ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-saw-vs-astralis-bo3-CVFySu5vH0SDxuYWfQA4dZ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-g2-bo3-xvu65ZQyrdlZTOhWO5j_dU.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-g2-bo3-xvu65ZQyrdlZTOhWO5j_dU.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-g2-bo3-xvu65ZQyrdlZTOhWO5j_dU.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-natus-vincere-bo5-gH3-PNkvLAQfRzQ4vYfvHF.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-natus-vincere-bo5-gH3-PNkvLAQfRzQ4vYfvHF.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-natus-vincere-bo5-gH3-PNkvLAQfRzQ4vYfvHF.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-vitality-bo3-5m4qp9mkJsfLWgwubFarcU.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-vitality-bo3-5m4qp9mkJsfLWgwubFarcU.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-spirit-vs-vitality-bo3-5m4qp9mkJsfLWgwubFarcU.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-virtuspro-vs-spirit-bo3-XB4X3ytt8vylJBM_oTdnRG.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-virtuspro-vs-spirit-bo3-XB4X3ytt8vylJBM_oTdnRG.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-virtuspro-vs-spirit-bo3-XB4X3ytt8vylJBM_oTdnRG.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-g2-bo3-07R4CPOHu_IwXUW--CcGcf.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-g2-bo3-07R4CPOHu_IwXUW--CcGcf.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-g2-bo3-07R4CPOHu_IwXUW--CcGcf.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-virtuspro-bo3-XYGQpZFqp_2Cviy1kmkwv9.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-virtuspro-bo3-XYGQpZFqp_2Cviy1kmkwv9.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-final-2024-vitality-vs-virtuspro-bo3-XYGQpZFqp_2Cviy1kmkwv9.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-big-bo3-92Fg8r8YwI6quMUMOhkAUB.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-big-bo3-92Fg8r8YwI6quMUMOhkAUB.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-big-bo3-92Fg8r8YwI6quMUMOhkAUB.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-falcons-bo3-cMSVgvzSy-YF4CQkG6ID5o.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-falcons-bo3-cMSVgvzSy-YF4CQkG6ID5o.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-falcons-bo3-cMSVgvzSy-YF4CQkG6ID5o.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-vitality-bo3-UVXuhGRpS9h-3nbFLvdUIa.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-vitality-bo3-UVXuhGRpS9h-3nbFLvdUIa.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-astralis-vs-vitality-bo3-UVXuhGRpS9h-3nbFLvdUIa.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-big-vs-heroic-bo3-EAL1DuTBwNQ_t71qeq7GUO.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-big-vs-heroic-bo3-EAL1DuTBwNQ_t71qeq7GUO.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-big-vs-heroic-bo3-EAL1DuTBwNQ_t71qeq7GUO.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-big-bo3-48DBapi4Si760J8VqHcDhM.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-big-bo3-48DBapi4Si760J8VqHcDhM.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-big-bo3-48DBapi4Si760J8VqHcDhM.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-heroic-bo3-bY8NaJ62yegXMl64mHFKoZ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-heroic-bo3-bY8NaJ62yegXMl64mHFKoZ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-cloud9-vs-heroic-bo3-bY8NaJ62yegXMl64mHFKoZ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-gamerlegion-bo3-OWnX6flEHx-39OqmpKC4RG.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-gamerlegion-bo3-OWnX6flEHx-39OqmpKC4RG.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-gamerlegion-bo3-OWnX6flEHx-39OqmpKC4RG.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-spirit-bo3-wkQcuWRWmK_1w0A7QGQscr.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-spirit-bo3-wkQcuWRWmK_1w0A7QGQscr.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-faze-vs-spirit-bo3-wkQcuWRWmK_1w0A7QGQscr.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-liquid-bo3-5O1CYFAtwd1nBgGY57UIRl.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-liquid-bo3-5O1CYFAtwd1nBgGY57UIRl.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-liquid-bo3-5O1CYFAtwd1nBgGY57UIRl.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-natus-vincere-bo3-YNZzdluz2vLlZbsmgT1lX3.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-natus-vincere-bo3-YNZzdluz2vLlZbsmgT1lX3.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-natus-vincere-bo3-YNZzdluz2vLlZbsmgT1lX3.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-9UQUT0ARSJABAVEj4WbTFq.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-9UQUT0ARSJABAVEj4WbTFq.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-9UQUT0ARSJABAVEj4WbTFq.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-ZOH6fKwctjOdPBiODowNJa.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-ZOH6fKwctjOdPBiODowNJa.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-g2-vs-ninjas-in-pyjamas-bo3-ZOH6fKwctjOdPBiODowNJa.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-faze-bo3-0R-skvX2qTBESZVM21Uryv.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-faze-bo3-0R-skvX2qTBESZVM21Uryv.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-faze-bo3-0R-skvX2qTBESZVM21Uryv.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-liquid-bo3-jjqsEOfbqtlxe-aopvnfvR.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-liquid-bo3-jjqsEOfbqtlxe-aopvnfvR.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-gamerlegion-vs-liquid-bo3-jjqsEOfbqtlxe-aopvnfvR.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-liquid-vs-faze-bo3-9h_974wV0r11Zqbjh-wEJB.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-liquid-vs-faze-bo3-9h_974wV0r11Zqbjh-wEJB.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-liquid-vs-faze-bo3-9h_974wV0r11Zqbjh-wEJB.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-complexity-bo3-C5vH-COaIIgjmNL_Y7uoWU.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-complexity-bo3-C5vH-COaIIgjmNL_Y7uoWU.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-complexity-bo3-C5vH-COaIIgjmNL_Y7uoWU.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-g2-bo3-ZX5miZ6d1IQGq7f25A2Ph-.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-g2-bo3-ZX5miZ6d1IQGq7f25A2Ph-.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-natus-vincere-vs-g2-bo3-ZX5miZ6d1IQGq7f25A2Ph-.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-ninjas-in-pyjamas-vs-complexity-bo3-KJMqzZurETGQaNYoqngsqC.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-ninjas-in-pyjamas-vs-complexity-bo3-KJMqzZurETGQaNYoqngsqC.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-ninjas-in-pyjamas-vs-complexity-bo3-KJMqzZurETGQaNYoqngsqC.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-og-vs-falcons-bo3-qPYxtTfkj5u8FDQSCEi2m1.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-og-vs-falcons-bo3-qPYxtTfkj5u8FDQSCEi2m1.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-og-vs-falcons-bo3-qPYxtTfkj5u8FDQSCEi2m1.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-spirit-vs-liquid-bo3--YrFcRwJABHqTXs2RWdXt-.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-spirit-vs-liquid-bo3--YrFcRwJABHqTXs2RWdXt-.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-spirit-vs-liquid-bo3--YrFcRwJABHqTXs2RWdXt-.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-RzfoyhFqt97HTnUNhIWyCr.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-RzfoyhFqt97HTnUNhIWyCr.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-RzfoyhFqt97HTnUNhIWyCr.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-W9tXWmBx4RhdWbXdAVeNx3.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-W9tXWmBx4RhdWbXdAVeNx3.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-big-bo3-W9tXWmBx4RhdWbXdAVeNx3.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-cloud9-bo3-kjls56b-gyvT8fLa5sfyVb.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-cloud9-bo3-kjls56b-gyvT8fLa5sfyVb.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-virtuspro-vs-cloud9-bo3-kjls56b-gyvT8fLa5sfyVb.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-astralis-bo3-Pgw9Phm4l9xhw5EIKMey08.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-astralis-bo3-Pgw9Phm4l9xhw5EIKMey08.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-astralis-bo3-Pgw9Phm4l9xhw5EIKMey08.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-falcons-bo3-PZRn7V890vrea2ZmYR6RjR.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-falcons-bo3-PZRn7V890vrea2ZmYR6RjR.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-falcons-bo3-PZRn7V890vrea2ZmYR6RjR.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-og-bo3-lT05HKwaUbDRDbtCBvj4ex.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-og-bo3-lT05HKwaUbDRDbtCBvj4ex.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-spring-groups-2024-vitality-vs-og-bo3-lT05HKwaUbDRDbtCBvj4ex.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-ence-bo3-1nhQhxLfdj9F0BD7AsyCy-.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-ence-bo3-1nhQhxLfdj9F0BD7AsyCy-.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-ence-bo3-1nhQhxLfdj9F0BD7AsyCy-.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-mouz-bo3-sIyiLm6YgwYKnf-1vhV8w1.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-mouz-bo3-sIyiLm6YgwYKnf-1vhV8w1.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-mouz-bo3-sIyiLm6YgwYKnf-1vhV8w1.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-vitality-bo3-GcqYdsbe4wbDz8TrHeGg0T.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-vitality-bo3-GcqYdsbe4wbDz8TrHeGg0T.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-cloud9-vs-vitality-bo3-GcqYdsbe4wbDz8TrHeGg0T.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-ence-vs-natus-vincere-bo3-dStyVZ6WIzcK-upLYQw6CJ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-ence-vs-natus-vincere-bo3-dStyVZ6WIzcK-upLYQw6CJ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-ence-vs-natus-vincere-bo3-dStyVZ6WIzcK-upLYQw6CJ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-g2-bo3-q1sdE-eIVJR3iWA1ZMZkol.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-g2-bo3-q1sdE-eIVJR3iWA1ZMZkol.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-g2-bo3-q1sdE-eIVJR3iWA1ZMZkol.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-heroic-bo3--7VeMkJIY0qTH-PBkDjI9c.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-heroic-bo3--7VeMkJIY0qTH-PBkDjI9c.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-heroic-bo3--7VeMkJIY0qTH-PBkDjI9c.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-mouz-bo3-nG87T-C_IsAv9NTQW5-h8p.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-mouz-bo3-nG87T-C_IsAv9NTQW5-h8p.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-mouz-bo3-nG87T-C_IsAv9NTQW5-h8p.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-vitality-bo3-ClpxEnxu3aH1RMZr76QdPj.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-vitality-bo3-ClpxEnxu3aH1RMZr76QdPj.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-faze-vs-vitality-bo3-ClpxEnxu3aH1RMZr76QdPj.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-heroic-vs-mouz-bo3-LaAVRpirlQFWEjDRV98Uwd.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-heroic-vs-mouz-bo3-LaAVRpirlQFWEjDRV98Uwd.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-heroic-vs-mouz-bo3-LaAVRpirlQFWEjDRV98Uwd.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-mouz-vs-g2-bo3-RV2ZzpoEPtHhvFrMQfzMxa.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-mouz-vs-g2-bo3-RV2ZzpoEPtHhvFrMQfzMxa.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-mouz-vs-g2-bo3-RV2ZzpoEPtHhvFrMQfzMxa.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-natus-vincere-vs-g2-bo3-kBFM-G_7fInl0UI1EoqFsN.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-natus-vincere-vs-g2-bo3-kBFM-G_7fInl0UI1EoqFsN.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-natus-vincere-vs-g2-bo3-kBFM-G_7fInl0UI1EoqFsN.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-m78qc_8zJ9vab4SEthdlsp.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-m78qc_8zJ9vab4SEthdlsp.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-m78qc_8zJ9vab4SEthdlsp.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-MJV0axAiNMvJWtC7C7FMR1.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-MJV0axAiNMvJWtC7C7FMR1.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\blast-premier-world-final-2023-vitality-vs-natus-vincere-bo3-MJV0axAiNMvJWtC7C7FMR1.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-lynn-vision-ancient-M87CpoFc3065IT8XNn65gN.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-lynn-vision-ancient-M87CpoFc3065IT8XNn65gN.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-lynn-vision-ancient-M87CpoFc3065IT8XNn65gN.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-mouz-bo3-2tq8EvA7zpZs-VZSqcnQaB.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-mouz-bo3-2tq8EvA7zpZs-VZSqcnQaB.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-astralis-vs-mouz-bo3-2tq8EvA7zpZs-VZSqcnQaB.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-astralis-bo3-TkLVtEeT2FtiIAgu7qxmvD.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-astralis-bo3-TkLVtEeT2FtiIAgu7qxmvD.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-astralis-bo3-TkLVtEeT2FtiIAgu7qxmvD.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-ninjas-in-pyjamas-bo3-wL9mKfCTS-bnp-Zv4qsJcc.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-ninjas-in-pyjamas-bo3-wL9mKfCTS-bnp-Zv4qsJcc.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-ninjas-in-pyjamas-bo3-wL9mKfCTS-bnp-Zv4qsJcc.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-tyloo-nuke-Ebx6OVyt3xu3UqsY7g38ct.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-tyloo-nuke-Ebx6OVyt3xu3UqsY7g38ct.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-ence-vs-tyloo-nuke-Ebx6OVyt3xu3UqsY7g38ct.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-faze-vs-ence-bo3-5YVEadQn2TMtkiKPizEkEq.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-faze-vs-ence-bo3-5YVEadQn2TMtkiKPizEkEq.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-faze-vs-ence-bo3-5YVEadQn2TMtkiKPizEkEq.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-faze-vs-ninjas-in-pyjamas-ancient-30H6zr4tZe7a8k0gxz0s4N.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\cs-asia-championships-2023-faze-vs-ninjas-in-pyjamas-ancient-30H6zr4tZe7a8k0gxz0s4N.rar
# INFO patool:     with input=
# ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\roobet-cup-2023-virtuspro-vs-spirit-bo3-vQxbwRuO42PuGP0NVsQ9bt.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\roobet-cup-2023-virtuspro-vs-spirit-bo3-vQxbwRuO42PuGP0NVsQ9bt.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-big-bo3-z6hIOyHX2Xba22SoB-YNmL.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-big-bo3-z6hIOyHX2Xba22SoB-YNmL.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-big-bo3-z6hIOyHX2Xba22SoB-YNmL.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-faze-bo3-nA9FzrskLVG8_jlknZTJAj.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-faze-bo3-nA9FzrskLVG8_jlknZTJAj.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-faze-bo3-nA9FzrskLVG8_jlknZTJAj.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-fnatic-bo3-PrE8KE3k48_amsejzYryEi.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-fnatic-bo3-PrE8KE3k48_amsejzYryEi.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-fnatic-bo3-PrE8KE3k48_amsejzYryEi.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-virtuspro-bo3-ENCa01I6WtRJ3ydNFB-AvJ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-virtuspro-bo3-ENCa01I6WtRJ3ydNFB-AvJ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-cloud9-vs-virtuspro-bo3-ENCa01I6WtRJ3ydNFB-AvJ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-m80-bo3-8sEQCp0zaG2inUFm6ZOwe8.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-m80-bo3-8sEQCp0zaG2inUFm6ZOwe8.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-m80-bo3-8sEQCp0zaG2inUFm6ZOwe8.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-mouz-bo3-uBfFO_IJlkwKFOq4f4uOyc.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-mouz-bo3-uBfFO_IJlkwKFOq4f4uOyc.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-complexity-vs-mouz-bo3-uBfFO_IJlkwKFOq4f4uOyc.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-mouz-bo3-QBw7uarrTd1AqjyDzc-6e5.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-mouz-bo3-QBw7uarrTd1AqjyDzc-6e5.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-mouz-bo3-QBw7uarrTd1AqjyDzc-6e5.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-saw-bo3-OzsUmLVvjMqlLW1sC9Tan-.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-saw-bo3-OzsUmLVvjMqlLW1sC9Tan-.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-saw-bo3-OzsUmLVvjMqlLW1sC9Tan-.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-virtuspro-bo3-r7EO0vQ7WUjws6h2lKF-2C.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-virtuspro-bo3-r7EO0vQ7WUjws6h2lKF-2C.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-faze-vs-virtuspro-bo3-r7EO0vQ7WUjws6h2lKF-2C.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-ninjas-in-pyjamas-bo3-6iVaParaf7r9nrM0X_nIUK.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-ninjas-in-pyjamas-bo3-6iVaParaf7r9nrM0X_nIUK.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-ninjas-in-pyjamas-bo3-6iVaParaf7r9nrM0X_nIUK.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-virtuspro-bo3-TIXlP91jgLe7XdTNek2mel.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-virtuspro-bo3-TIXlP91jgLe7XdTNek2mel.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-fnatic-vs-virtuspro-bo3-TIXlP91jgLe7XdTNek2mel.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-hkFi0TfEx9BObmJ_9GHH_K.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-hkFi0TfEx9BObmJ_9GHH_K.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-hkFi0TfEx9BObmJ_9GHH_K.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-lGjFzt1wWha02Yfx7n_6vg.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-lGjFzt1wWha02Yfx7n_6vg.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-furia-vs-big-bo3-lGjFzt1wWha02Yfx7n_6vg.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-big-bo3-NXFf-Tfj4iLSY190M4J04L.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-big-bo3-NXFf-Tfj4iLSY190M4J04L.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-big-bo3-NXFf-Tfj4iLSY190M4J04L.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-nouns-bo3-iKU7Xm9F7AHq9oQMoQm7hQ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-nouns-bo3-iKU7Xm9F7AHq9oQMoQm7hQ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-nouns-bo3-iKU7Xm9F7AHq9oQMoQm7hQ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-virtuspro-bo3-dRNUnO45gXILSlEK6WpiaJ.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-virtuspro-bo3-dRNUnO45gXILSlEK6WpiaJ.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-heroic-vs-virtuspro-bo3-dRNUnO45gXILSlEK6WpiaJ.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-faze-bo3-7x4_XQuVyHrhEBbvAHH9rx.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-faze-bo3-7x4_XQuVyHrhEBbvAHH9rx.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-faze-bo3-7x4_XQuVyHrhEBbvAHH9rx.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-virtuspro-bo3-dHcBtPQsV7W-pZx2viCD5Q.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-virtuspro-bo3-dHcBtPQsV7W-pZx2viCD5Q.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-virtuspro-bo3-dHcBtPQsV7W-pZx2viCD5Q.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-wildcard-bo3-YqBypbuEEGujlipXlI3-hy.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-wildcard-bo3-YqBypbuEEGujlipXlI3-hy.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-monte-vs-wildcard-bo3-YqBypbuEEGujlipXlI3-hy.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-mouz-vs-m80-bo3-qZbKFRfdV0XsbwIWiiTRfN.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-mouz-vs-m80-bo3-qZbKFRfdV0XsbwIWiiTRfN.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-mouz-vs-m80-bo3-qZbKFRfdV0XsbwIWiiTRfN.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-ninjas-in-pyjamas-vs-virtuspro-bo3-hZMHo4HYjYRM_rTdbZFf07.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-ninjas-in-pyjamas-vs-virtuspro-bo3-hZMHo4HYjYRM_rTdbZFf07.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-ninjas-in-pyjamas-vs-virtuspro-bo3-hZMHo4HYjYRM_rTdbZFf07.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-nouns-vs-furia-bo3-VtQ0jJEeXbXtt27JJY8nFg.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-nouns-vs-furia-bo3-VtQ0jJEeXbXtt27JJY8nFg.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-nouns-vs-furia-bo3-VtQ0jJEeXbXtt27JJY8nFg.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-saw-vs-monte-bo3-XBJeew1RQ2Ry2MdGMpXPS-.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-saw-vs-monte-bo3-XBJeew1RQ2Ry2MdGMpXPS-.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-saw-vs-monte-bo3-XBJeew1RQ2Ry2MdGMpXPS-.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-complexity-bo3-a-LqgDyhD2-0eq6lbKFDpT.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-complexity-bo3-a-LqgDyhD2-0eq6lbKFDpT.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-complexity-bo3-a-LqgDyhD2-0eq6lbKFDpT.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-monte-bo3-AtVL_u7jdQvVd66rO00AKH.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-monte-bo3-AtVL_u7jdQvVd66rO00AKH.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-monte-bo3-AtVL_u7jdQvVd66rO00AKH.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-mouz-bo3-7yOh0SXos1yDpSXW5-0gf3.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-mouz-bo3-7yOh0SXos1yDpSXW5-0gf3.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-spirit-vs-mouz-bo3-7yOh0SXos1yDpSXW5-0gf3.rar extracted to `../../data/matches-raw/cs2/2023'.
# INFO patool: Extracting ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-wildcard-vs-saw-bo3-CpuwzEpRS0SaX-xMFVIMwL.rar ...
# INFO patool: running "C:\Program Files\7-Zip\7z.EXE" x -o../../data/matches-raw/cs2/2023 -- ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-wildcard-vs-saw-bo3-CpuwzEpRS0SaX-xMFVIMwL.rar
# INFO patool:     with input=
# INFO patool: ... ../../data/matches-raw/cs2/2023/zip\thunderpick-world-championship-2023-wildcard-vs-saw-bo3-CpuwzEpRS0SaX-xMFVIMwL.rar extracted to `../../data/matches-raw/cs2/2023'.
