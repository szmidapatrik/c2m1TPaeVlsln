# %% [markdown]
# ## HLTV stat scrape
# ### Get hltv links to player profiles
# ### Scrape stats

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
from time import sleep
import random
import csv


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------



def get_player_profile_links(url):
    
    browser = webdriver.Firefox()

    browser.get(url)
    sleep(random.uniform(2, 3))
    allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
    allowCookies.click()
    sleep(2)

    player_url = []
    
    players = browser.find_elements(By.CSS_SELECTOR, 'table.stats-table tbody tr')
    for player in players:
        link = player.find_element(By.TAG_NAME, 'a').get_attribute('href')
        player_url.append(link)

    browser.quit()
    
    return player_url


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_link_and_decline_cookies(url):
    
    browser = webdriver.Firefox()
    
    sleep(0.2)
    browser.get(url)
    sleep(3.2)
    
    allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
    sleep(random.uniform(0.4, 1.2))
    allowCookies.click()
    
    return browser


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_overview_stats(url, stats):
    
    browser = get_link_and_decline_cookies(url)
    
    # Highlighted stats
    stats['player_name'] = browser.find_element(By.CSS_SELECTOR, 'h1.summaryNickname').text
    stats['rating_2.0'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[0].text
    stats['DPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[1].text
    stats['KAST'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[2].text[:-1]
    stats['Impact'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[3].text
    stats['ADR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[4].text
    stats['KPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[5].text
    
    # Other stats
    stats['total_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[0].text.replace('Total kills\n', '')
    stats['HS%'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[1].text.replace('Headshot %\n', '')[:-1]
    stats['total_deaths'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[2].text.replace('Total deaths\n', '')
    stats['KD_ratio'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[3].text.replace('K/D Ratio\n', '')
    stats['dmgPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[4].text.replace('Damage / Round\n', '')
    stats['grenade_dmgPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[5].text.replace('Grenade dmg / Round\n', '')
    stats['maps_played'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[6].text.replace('Maps played\n', '')
    stats['rounds_played'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[7].text.replace('Rounds played\n', '')
    stats['KPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[8].text.replace('Kills / round\n', '')
    stats['APR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[9].text.replace('Assists / round\n', '')
    stats['saved_by_teammatePR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[11].text.replace('Saved by teammate / round\n', '')
    stats['saved_teammatesPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[12].text.replace('Saved teammates / round\n', '')
    
    browser.quit()
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_individual_stats(url, stats):
    
    url_individual = url.replace('/players/', '/players/individual/')
    browser = get_link_and_decline_cookies(url_individual)

    stats['rounds_with_kils'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[4].text.replace('Rounds with kills\n', '')
    stats['KD_diff'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[5].text.replace('Kill - Death difference\n', '')
    
    stats['total_opening_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[6].text.replace('Total opening kills\n', '')
    stats['total_opening_deaths'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[7].text.replace('Total opening deaths\n', '')
    stats['opening_kill_ratio'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[8].text.replace('Opening kill ratio\n', '')
    stats['opening_kill_rating'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[9].text.replace('Opening kill rating\n', '')
    stats['team_W%_after_opening'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[10].text[:-1].replace('Team win percent after first kill\n', '')
    stats['opening_kill_in_W_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[11].text[:-1].replace('First kill in won rounds\n', '')
    
    stats['0_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[12].text.replace('0 kill rounds\n', '')
    stats['1_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[13].text.replace('1 kill rounds\n', '')
    stats['2_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[14].text.replace('2 kill rounds\n', '')
    stats['3_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[15].text.replace('3 kill rounds\n', '')
    stats['4_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[16].text.replace('4 kill rounds\n', '')
    stats['5_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[17].text.replace('5 kill rounds\n', '')
    
    stats['rifle_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[18].text.replace('Rifle kills\n', '')
    stats['sniper_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[19].text.replace('Sniper kills\n', '')
    stats['smg_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[20].text.replace('SMG kills\n', '')
    stats['pistol_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[21].text.replace('Pistol kills\n', '')
    stats['grenade_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[22].text.replace('Grenade\n', '')
    stats['other_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[23].text.replace('Other\n', '')
    
    browser.quit()
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_match_stats(url, stats):
    
    url_match = url.replace('/players/', '/players/matches/')
    browser = get_link_and_decline_cookies(url_match)

    stats['maps_W%'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[1].text[:-1]
    stats['rating_2.0_1+'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[2].text[:-1]
    stats['rating_2.0_1+_streak'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[3].text
        
    browser.quit()
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_rating_1_0_table(url, stats):
    
    url_rating = url.replace('/players/', '/players/career/')
    browser = get_link_and_decline_cookies(url_rating)
    
    year = browser.find_elements(By.TAG_NAME, 'tr')
    rating_one_stats = {}
    for item in year:
        
        if (item.text.startswith('Past 3 months') or item.text.startswith('Period')):
            continue
        
        values = item.find_elements(By.TAG_NAME, 'td')
        
        if (len(values) != 5):
                continue
        
        rating_one_stats['rating_1.0_all_' + values[0].text] = values[1].text
        rating_one_stats['rating_1.0_online_' + values[0].text] = values[2].text
        rating_one_stats['rating_1.0_lan_' + values[0].text] = values[3].text
        rating_one_stats['rating_1.0_major_' + values[0].text] = values[4].text
        
        if item.text.startswith('Career'):
            stats['rating_1.0_all_' + values[0].text] = values[1].text
            stats['rating_1.0_online_' + values[0].text] = values[2].text
            stats['rating_1.0_lan_' + values[0].text] = values[3].text
            stats['rating_1.0_major_' + values[0].text] = values[4].text
    
    stats['rating_1.0_data'] = rating_one_stats
    browser.quit()
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_weapon_stats(url, stats):
    
    url_weapon = url.replace('/players/', '/players/weapon/')
    browser = get_link_and_decline_cookies(url_weapon)
    
    weapon_stats = {}
    weapons = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')
    for weapon in weapons:
        weapon_name = weapon.text.split('\n')[0].split(' ')[1]
        weapon_stats['kills_' + weapon_name] = weapon.text.split('\n')[1]    
    stats['weapon_data'] = weapon_stats
    
    browser.quit()
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_clutch_stats(url, stats):
    
    url_clutch_type_list = ['1on1', '1on2', '1on3', '1on4', '1on5']
    url_clutch = url.replace('/players/', '/players/clutches/')
    url_clutch_array = url_clutch.split('/')
    
    
    for clutch_type in url_clutch_type_list:
        
        url_XonX = url_clutch_array.copy()
        url_XonX.insert(7, clutch_type)
        url_clutch = '/'.join(url_XonX)
        browser = get_link_and_decline_cookies(url_clutch)
        
        clutches = browser.find_elements(By.CSS_SELECTOR, 'div.value')
        stats['clutches_won_' + clutch_type] = clutches[0].text
        if clutch_type == '1on1':
            stats['clutches_lost_' + clutch_type] = clutches[1].text 
        
        
        browser.quit()
    
    return stats


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def create_file(stats, file_name):
    file_path = '../../data/player-stats/scraped-in-2024/{}'.format(file_name)
    with open(file_path, 'w+', newline='') as f:
        writer = csv.writer(f)
        columns = []
        for x in stats:
            columns.append(x)
        writer.writerow(columns)


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def write_to_csv(stats, file_name):
    file_path = '../../data/player-stats/scraped-in-2024/{}'.format(file_name)
    with open(file_path, 'a', newline='') as f:
        writer = csv.writer(f)
        values = []
        for x in stats:
            values.append(stats[x])
        writer.writerow(values)
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def write_url_done(url, file_name):
        
    # Save parsed demo to list
    f = open('./' + file_name, 'a+')
    f.write("%s\n" % url)
    f.close()
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

 
def handle_scrape_error(link_with_error):
    f = open('./errors.txt', 'a+')
    f.write('Error while scraping {}, skipping file\n'.format(link_with_error))
    f.close()
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

 
def get_player_stats(url, txt_file_name, csv_file_name, year):

    players = get_player_profile_links(url)
    
    for idx, url_player in enumerate(players):

        url_player = url_player.split('?')[0] + "?startDate={}-01-01&endDate={}-12-31".format(year, year)

        # Check wether the demo is alreay parsed
        txt_file_path = './{}'.format(txt_file_name)
        with open(txt_file_path) as f:
            lines = f.read().splitlines()
            if url_player in lines:
                continue
            
        print(url_player)
        
        try:
            stats = get_overview_stats(url_player, {})
            stats = get_individual_stats(url_player, stats)
            stats = get_match_stats(url_player, stats)
            stats = get_rating_1_0_table(url_player, stats)
            stats = get_weapon_stats(url_player, stats)
            stats = get_clutch_stats(url_player, stats)
            
            # if idx == 0:
            #     create_file(stats, csv_file_name)
            write_to_csv(stats, csv_file_name)
        except:
            handle_scrape_error(url_player)
        write_url_done(url_player, txt_file_name)

# %%
# Inferno stats
get_player_stats('https://www.hltv.org/stats/players?startDate=2012-01-01&endDate=2022-01-01&maps=de_inferno&rankingFilter=All')

# %%
# All player stats
SAVE_TXT = 'url_done.txt'
SAVE_CSV = 'player_stats_2021.csv'
get_player_stats('https://www.hltv.org/stats/players?startDate=all&endDate=2022-01-01', SAVE_TXT, SAVE_CSV, 2021)
# Out:
# https://www.hltv.org/stats/players/4726/jaxi?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17956/jabbi?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10570/dzt?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9245/tsogoo?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8726/facecrack?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/44/barbarr?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8374/bodyy?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19232/jiaym?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17116/ragga?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/11258/fr0slev?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16811/mistem?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9254/mopoz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20968/soulfly?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7700/robiin?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/339/ange1?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10372/kaboose?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12521/art?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/11329/leo-drk?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/630/mutiris?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9130/drone?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12872/apocdud?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8125/dimaoneshot?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/2161/noktse?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7873/dephh?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8324/morelz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16947/perfecto?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12089/vanity?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9298/truth?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8875/gade?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9818/uli?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7808/freakazoid?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17936/bq?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8488/zedko?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12822/vini?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7529/saggerton?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/18571/cypher?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10052/fitch?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16717/br0?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/14495/emiya?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20275/techno?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/6904/styko?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16495/kory?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/18506/s1ren?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13989/ryotzz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19733/demqq?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8871/lukki?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/21784/simke?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12593/j1rah?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8508/davey?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/884/xizt?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20465/arrozdoce?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8082/azr?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7687/nitr0?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13157/jerry?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/1485/rubino?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19187/xfl0ud?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12304/stev0se?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19739/ex3rcice?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20564/d4rty?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12088/ryann?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/15176/cryptic?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/735/dosia?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10611/fadey?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/334/adren?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13093/deathzz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19015/bymas?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20284/maaryy?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8716/deadfox?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9221/reversive?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/11996/daffu?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7438/anger?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20878/adamb?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/15885/pr?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17792/ice?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19284/prosus?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7499/spiidi?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16432/manguss?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10436/sxe?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17181/naitte?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16820/siuhy?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/16529/llamas?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20282/krasnal?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12781/k1to?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/5061/percy?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/2799/bubble?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/11922/alle?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9636/burnruok?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/11747/jnt?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/555/bit?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/284/jackz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/2241/roman?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12244/sergiz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/15949/peppzor?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9903/notan?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13148/radifaction?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9571/cj-da-k1ng?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20300/kraghen?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13240/lack1?startDate=2021-01-01&endDate=2021-12-31
