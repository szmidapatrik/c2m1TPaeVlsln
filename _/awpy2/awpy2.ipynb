# %%
pip install awpy --pre
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      -------------------- ------------------- 30.7/60.9 kB 1.3 MB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 817.1 kB/s eta 0:00:00
# ...
#   Using cached setuptools-70.0.0-py3-none-any.whl.metadata (5.9 kB)
# ...
#      ---------------------------------------- 0.0/57.6 kB ? eta -:--:--
#      ---------------------------------------- 57.6/57.6 kB 3.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/165.5 kB ? eta -:--:--
#      -------------------------------------  163.8/165.5 kB 5.0 MB/s eta 0:00:01
#      -------------------------------------- 165.5/165.5 kB 3.4 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#     --------------------------------------- 0.1/2.4 MB ? eta -:--:--
# ...

# %%
from awpy import Demo

dem = Demo("natus-vincere-vs-faze-m2-mirage.dem")

# %%
dem.ticks
# Out:
#                                                  inventory  is_bomb_planted  \
# 12400    [knife_butterfly, Glock-18, C4, Smoke Grenade,...            False
# 12401                              [knife_butterfly, P250]            False
# 12402    [knife_m9_bayonet, Smoke Grenade, Flashbang, G...            False
# 12403              [knife_butterfly, USP-S, Smoke Grenade]            False
# 12404          [knife_m9_bayonet, Glock-18, Decoy Grenade]            False
# ...                                                    ...              ...
# 2239455  [knife_m9_bayonet, Five-SeveN, AK-47, Molotov,...             True
# 2239456  [knife_butterfly, USP-S, Smoke Grenade, M4A1-S...             True
# 2239457                                                 []             True
# 2239458                                                 []             True
# 2239459                                                 []             True
#
# ...
