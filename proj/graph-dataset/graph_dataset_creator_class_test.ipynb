# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sys
import os

pd.set_option('display.max_columns', 100)

sys.path.append(os.path.abspath('./'))
from graph_data_creator import TabularDataCreator

# %%
tdc = TabularDataCreator()

# %%
tdc.format_match_data(
    'BLAST-Premier-Fall-Final-2022-faze-vs-heroic-bo3faze-vs-heroic-m2-inferno.dem.csv',
    '../../data/demo-parsed/2022',
    '../../data/player-stats/scraped-in-2024/2021/player_stats_2021_imputed.csv',
    tick_number=1,
    add_numerical_match_id=True,
    numerical_match_id=1000)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 tdc.format_match_data(
#       2     'BLAST-Premier-Fall-Final-2022-faze-vs-heroic-bo3faze-vs-heroic-m2-inferno.dem.csv',
#       3     '../../data/demo-parsed/2022',
#       4     '../../data/player-stats/scraped-in-2024/2021/player_stats_2021_imputed.csv',
#       5     tick_number=1,
#       6     add_numerical_match_id=True,
#       7     numerical_match_id=1000)
#
# File e:\csgo-gnn\proj\graph-dataset\graph_data_creator.py:75, in TabularDataCreator.format_match_data(self, match_file_name, tabular_data_folder_path, player_stats_data_path, tick_number, missing_player_stats_data_path, add_numerical_match_id, numerical_match_id)
#      73 players = self.__PLAYER_player_dataset_create__(pf, self.tick_number)
#      74 # 5.
# ...

# %%
tdc.create_missing_player_stats_data('../../data/player-stats/scraped-in-2024/2021/player_stats_2021_imputed.csv')
# Out:
#      rating_2.0       DPR       KAST    Impact        ADR       KPR  \
# 0      1.013291  0.652501  69.736122  1.014406  74.546446  0.681611
# 1      1.007021  0.645810  69.893738  1.033672  75.965198  0.671662
# 2      1.014216  0.645240  69.664609  1.046973  75.475971  0.677682
# 3      1.008341  0.649440  69.602542  1.021241  75.472216  0.686151
# 4      1.003378  0.647772  69.760314  1.023647  75.439915  0.671529
# ..          ...       ...        ...       ...        ...       ...
# 995    1.014412  0.650667  69.648692  1.045648  75.696885  0.676211
# 996    1.008460  0.642303  69.661614  1.019570  75.904672  0.681257
# 997    1.008059  0.649726  69.756531  1.034847  76.213448  0.673523
# 998    1.011197  0.648081  69.527587  1.019634  76.142132  0.683580
# 999    0.997972  0.649685  69.755116  1.050970  75.771640  0.677868
#
#      total_kills        HS%  total_deaths  KD_ratio      dmgPR  grenade_dmgPR  \
# ...
