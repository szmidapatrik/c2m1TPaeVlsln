# %%
from awpy import Demo

import torch
from torch_geometric_temporal.signal import DynamicHeteroGraphTemporalSignal

import pandas as pd
import polars as pl
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from termcolor import colored
import time
import json
import pickle
import random
import sys
import os

pd.set_option('display.max_columns', 100)
pd.set_option('future.no_silent_downcasting', True)

pl.Config.set_tbl_rows(10)

sys.path.append(os.path.abspath('../../package'))

from CS2.graph import TabularGraphSnapshot, HeteroGraphSnapshot, TemporalHeteroGraphSnapshot
from CS2.token import Tokenizer
from CS2.preprocess import Dictionary, NormalizePosition, NormalizeTabularGraphSnapshot, ImputeTabularGraphSnapshot
from CS2.visualize import HeteroGraphVisualizer

DATA_PATH = '../../data/matches-processed/cs2/temporal-hetero-graph/'
DATA_SAVE_PATH = '../../data/matches-processed/cs2/temporal-hetero-graph-round/'
PROCESS_SAVE_PATH = './parses/temp-hetero-parse-2024.11.06_round/'

# Path constants
PATH_TEMP_GRAPH_DATA_20 = '../../data/matches-processed/cs2/temporal-hetero-graph/temporal-hetero-graph_20/'
PATH_TEMP_GRAPH_DATA_60 = '../../data/matches-processed/cs2/temporal-hetero-graph/temporal-hetero-graph-start_end_60/'
PATH_TEMP_GRAPH_DATA_R = '../../data/matches-processed/cs2/temporal-hetero-graph/temporal-hetero-graph-round/'

# %% [markdown]
# # Create Temporal dataset

# %%
hetero_graph_matches = [f for f in os.listdir(DATA_PATH) if os.path.isfile(os.path.join(DATA_PATH, f)) and f not in ['train.pt', 'val.pt']]
processed_matches = []

dataset_lengths = []
overall_length = 0

# Load processed matches
if os.path.exists(os.path.join(PROCESS_SAVE_PATH, 'process.txt')):
    with open(os.path.join(PROCESS_SAVE_PATH, 'process.txt'), 'r') as f:
        processed_matches = f.readlines()

# Remove whitespace characters like `\n` at the end of each line
for match_idx in range(len(processed_matches)):
    processed_matches[match_idx] = processed_matches[match_idx].strip()


for file in hetero_graph_matches:

    if file in processed_matches:
        print(colored(f'{file} already processed. Skipping...', 'yellow'))
        continue

    print(colored(f'Processing {file}...', 'light_blue'))

    match = torch.load(DATA_PATH + file, weights_only=False)
    thgs = TemporalHeteroGraphSnapshot()
    dyn_graphs = None
    dyn_graphs = thgs.process_match(match, interval=60, round_process_strategy='round')

    dataset_lengths.append(len(dyn_graphs))
    overall_length += len(dyn_graphs)

    print('DTDG Dataset Length:', len(dyn_graphs))
    print(colored(f'{file} processed.', 'green'))

    torch.save(dyn_graphs, DATA_SAVE_PATH + file)

    with open(os.path.join(PROCESS_SAVE_PATH, 'process.txt'), 'a') as f:
        f.write(f'{file}\n')
# Out:
# Processing 100000.pt...
# DTDG Dataset Length: 18
# 100000.pt processed.
# Processing 100001.pt...
# DTDG Dataset Length: 21
# 100001.pt processed.
# Processing 100002.pt...
# DTDG Dataset Length: 24
# 100002.pt processed.
# Processing 100003.pt...
# DTDG Dataset Length: 20
# 100003.pt processed.
# Processing 100004.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100004.0 at round                         0.1666666716337204. Skipping the round.
# DTDG Dataset Length: 20
# 100004.pt processed.
# Processing 100005.pt...
# DTDG Dataset Length: 21
# 100005.pt processed.
# Processing 100006.pt...
# DTDG Dataset Length: 20
# 100006.pt processed.
# Processing 100007.pt...
# DTDG Dataset Length: 18
# 100007.pt processed.
# Processing 100008.pt...
# DTDG Dataset Length: 24
# 100008.pt processed.
# Processing 100009.pt...
# DTDG Dataset Length: 22
# 100009.pt processed.
# Processing 100010.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100010.0 at round                         0.8333333134651184. Skipping the round.
# DTDG Dataset Length: 0
# 100010.pt processed.
# Processing 100011.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100011.0 at round                         0.5416666865348816. Skipping the round.
# DTDG Dataset Length: 5
# 100011.pt processed.
# Processing 100012.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100012.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 5
# 100012.pt processed.
# Processing 100013.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.9166666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100013.0 at round                         0.9583333134651184. Skipping the round.
# DTDG Dataset Length: 3
# 100013.pt processed.
# Processing 100014.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100014.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 3
# 100014.pt processed.
# Processing 100015.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.875. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.9166666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100015.0 at round                         0.9583333134651184. Skipping the round.
# DTDG Dataset Length: 2
# 100015.pt processed.
# Processing 100016.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100016.0 at round                         0.5833333134651184. Skipping the round.
# DTDG Dataset Length: 3
# 100016.pt processed.
# Processing 100017.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         0.9583333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         1.0. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         1.0416666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         1.0833333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         1.1666666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100017.0 at round                         1.2083333730697632. Skipping the round.
# DTDG Dataset Length: 8
# 100017.pt processed.
# Processing 100018.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100018.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100018.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100018.0 at round                         0.625. Skipping the round.
# DTDG Dataset Length: 20
# 100018.pt processed.
# Processing 100019.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100019.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100019.0 at round                         0.5416666865348816. Skipping the round.
# DTDG Dataset Length: 19
# 100019.pt processed.
# Processing 100020.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100020.0 at round                         0.0416666679084301. Skipping the round.
# DTDG Dataset Length: 18
# 100020.pt processed.
# Processing 100021.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100021.0 at round                         0.1666666716337204. Skipping the round.
# DTDG Dataset Length: 17
# 100021.pt processed.
# Processing 100022.pt...
# DTDG Dataset Length: 20
# 100022.pt processed.
# Processing 100023.pt...
# DTDG Dataset Length: 24
# 100023.pt processed.
# Processing 100024.pt...
# DTDG Dataset Length: 24
# 100024.pt processed.
# Processing 100025.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100025.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100025.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100025.0 at round                         0.8333333134651184. Skipping the round.
# DTDG Dataset Length: 18
# 100025.pt processed.
# Processing 100026.pt...
# DTDG Dataset Length: 23
# 100026.pt processed.
# Processing 100027.pt...
# DTDG Dataset Length: 24
# 100027.pt processed.
# Processing 100028.pt...
# DTDG Dataset Length: 21
# 100028.pt processed.
# Processing 100029.pt...
# DTDG Dataset Length: 18
# 100029.pt processed.
# Processing 100030.pt...
# DTDG Dataset Length: 17
# 100030.pt processed.
# Processing 100031.pt...
# DTDG Dataset Length: 16
# 100031.pt processed.
# Processing 100032.pt...
# DTDG Dataset Length: 17
# 100032.pt processed.
# Processing 100033.pt...
# DTDG Dataset Length: 18
# 100033.pt processed.
# Processing 100034.pt...
# DTDG Dataset Length: 23
# 100034.pt processed.
# Processing 100035.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100035.0 at round                         0.4166666567325592. Skipping the round.
# DTDG Dataset Length: 22
# 100035.pt processed.
# Processing 100036.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100036.0 at round                         0.5833333134651184. Skipping the round.
# DTDG Dataset Length: 17
# 100036.pt processed.
# Processing 100037.pt...
# DTDG Dataset Length: 22
# 100037.pt processed.
# Processing 100038.pt...
# DTDG Dataset Length: 22
# 100038.pt processed.
# Processing 100039.pt...
# DTDG Dataset Length: 20
# 100039.pt processed.
# Processing 100040.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100040.0 at round                         0.625. Skipping the round.
# DTDG Dataset Length: 0
# 100040.pt processed.
# Processing 100041.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.875. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.9166666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         0.9583333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.0. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.0416666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.0833333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.1666666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.2083333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.2916666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.3333333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.4166666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.4583333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100041.0 at round                         1.5. Skipping the round.
# DTDG Dataset Length: 0
# 100041.pt processed.
# Processing 100042.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100042.0 at round                         0.75. Skipping the round.
# DTDG Dataset Length: 0
# 100042.pt processed.
# Processing 100043.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100043.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 12
# 100043.pt processed.
# Processing 100044.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.2083333283662796. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.8333333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.875. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.9166666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         0.9583333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.0. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.0416666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.0833333730697632. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.125. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.1666666269302368. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100044.0 at round                         1.2083333730697632. Skipping the round.
# DTDG Dataset Length: 3
# 100044.pt processed.
# Processing 100045.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.3333333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.5833333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.7916666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100045.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 12
# 100045.pt processed.
# Processing 100046.pt...
# DTDG Dataset Length: 20
# 100046.pt processed.
# Processing 100047.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100047.0 at round                         0.75. Skipping the round.
# DTDG Dataset Length: 18
# 100047.pt processed.
# Processing 100048.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100048.0 at round                         0.5833333134651184. Skipping the round.
# DTDG Dataset Length: 35
# 100048.pt processed.
# Processing 100049.pt...
# DTDG Dataset Length: 22
# 100049.pt processed.
# Processing 100050.pt...
# DTDG Dataset Length: 21
# 100050.pt processed.
# Processing 100051.pt...
# DTDG Dataset Length: 35
# 100051.pt processed.
# Processing 100052.pt...
# DTDG Dataset Length: 18
# 100052.pt processed.
# Processing 100053.pt...
# DTDG Dataset Length: 22
# 100053.pt processed.
# Processing 100054.pt...
# DTDG Dataset Length: 23
# 100054.pt processed.
# Processing 100055.pt...
# DTDG Dataset Length: 24
# 100055.pt processed.
# Processing 100056.pt...
# DTDG Dataset Length: 28
# 100056.pt processed.
# Processing 100057.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100057.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 21
# 100057.pt processed.
# Processing 100058.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100058.0 at round                         0.4583333432674408. Skipping the round.
# DTDG Dataset Length: 18
# 100058.pt processed.
# Processing 100059.pt...
# DTDG Dataset Length: 35
# 100059.pt processed.
# Processing 100060.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100060.0 at round                         1.25. Skipping the round.
# DTDG Dataset Length: 29
# 100060.pt processed.
# Processing 100061.pt...
# DTDG Dataset Length: 23
# 100061.pt processed.
# Processing 100062.pt...
# DTDG Dataset Length: 20
# 100062.pt processed.
# Processing 100063.pt...
# DTDG Dataset Length: 36
# 100063.pt processed.
# Processing 100064.pt...
# DTDG Dataset Length: 22
# 100064.pt processed.
# Processing 100065.pt...
# DTDG Dataset Length: 19
# 100065.pt processed.
# Processing 100066.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100066.0 at round                         0.3333333432674408. Skipping the round.
# DTDG Dataset Length: 28
# 100066.pt processed.
# Processing 100067.pt...
# DTDG Dataset Length: 20
# 100067.pt processed.
# Processing 100068.pt...
# DTDG Dataset Length: 15
# 100068.pt processed.
# Processing 100069.pt...
# DTDG Dataset Length: 20
# 100069.pt processed.
# Processing 100070.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100070.0 at round                         0.25. Skipping the round.
# DTDG Dataset Length: 19
# 100070.pt processed.
# Processing 100071.pt...
# DTDG Dataset Length: 21
# 100071.pt processed.
# Processing 100072.pt...
# DTDG Dataset Length: 29
# 100072.pt processed.
# Processing 100073.pt...
# DTDG Dataset Length: 22
# 100073.pt processed.
# Processing 100074.pt...
# DTDG Dataset Length: 24
# 100074.pt processed.
# Processing 100075.pt...
# DTDG Dataset Length: 24
# 100075.pt processed.
# Processing 100076.pt...
# DTDG Dataset Length: 14
# 100076.pt processed.
# Processing 100077.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100077.0 at round                         0.625. Skipping the round.
# DTDG Dataset Length: 17
# 100077.pt processed.
# Processing 100078.pt...
# DTDG Dataset Length: 21
# 100078.pt processed.
# Processing 100079.pt...
# DTDG Dataset Length: 23
# 100079.pt processed.
# Processing 100080.pt...
# DTDG Dataset Length: 22
# 100080.pt processed.
# Processing 100081.pt...
# DTDG Dataset Length: 30
# 100081.pt processed.
# Processing 100082.pt...
# DTDG Dataset Length: 19
# 100082.pt processed.
# Processing 100083.pt...
# DTDG Dataset Length: 19
# 100083.pt processed.
# Processing 100084.pt...
# DTDG Dataset Length: 22
# 100084.pt processed.
# Processing 100085.pt...
# DTDG Dataset Length: 24
# 100085.pt processed.
# Processing 100086.pt...
# DTDG Dataset Length: 21
# 100086.pt processed.
# Processing 100087.pt...
# DTDG Dataset Length: 21
# 100087.pt processed.
# Processing 100088.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100088.0 at round                         0.5. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100088.0 at round                         0.5416666865348816. Skipping the round.
# DTDG Dataset Length: 33
# 100088.pt processed.
# Processing 100089.pt...
# DTDG Dataset Length: 18
# 100089.pt processed.
# Processing 100090.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100090.0 at round                         0.5416666865348816. Skipping the round.
# DTDG Dataset Length: 28
# 100090.pt processed.
# Processing 100091.pt...
# DTDG Dataset Length: 22
# 100091.pt processed.
# Processing 100092.pt...
# DTDG Dataset Length: 21
# 100092.pt processed.
# Processing 100093.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100093.0 at round                         1.25. Skipping the round.
# DTDG Dataset Length: 34
# 100093.pt processed.
# Processing 100094.pt...
# DTDG Dataset Length: 30
# 100094.pt processed.
# Processing 100095.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100095.0 at round                         0.0833333358168602. Skipping the round.
# DTDG Dataset Length: 19
# 100095.pt processed.
# Processing 100096.pt...
# DTDG Dataset Length: 22
# 100096.pt processed.
# Processing 100097.pt...
# DTDG Dataset Length: 20
# 100097.pt processed.
# Processing 100098.pt...
# DTDG Dataset Length: 16
# 100098.pt processed.
# Processing 100099.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100099.0 at round                         0.25. Skipping the round.
# DTDG Dataset Length: 15
# 100099.pt processed.
# Processing 100100.pt...
# DTDG Dataset Length: 22
# 100100.pt processed.
# Processing 100101.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100101.0 at round                         0.5833333134651184. Skipping the round.
# DTDG Dataset Length: 40
# 100101.pt processed.
# Processing 100102.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100102.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100102.0 at round                         0.4166666567325592. Skipping the round.
# DTDG Dataset Length: 22
# 100102.pt processed.
# Processing 100103.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100103.0 at round                         0.7916666865348816. Skipping the round.
# DTDG Dataset Length: 18
# 100103.pt processed.
# Processing 100104.pt...
# DTDG Dataset Length: 22
# 100104.pt processed.
# Processing 100105.pt...
# DTDG Dataset Length: 23
# 100105.pt processed.
# Processing 100106.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100106.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100106.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100106.0 at round                         0.75. Skipping the round.
# DTDG Dataset Length: 18
# 100106.pt processed.
# Processing 100107.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100107.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100107.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100107.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100107.0 at round                         0.6666666865348816. Skipping the round.
# DTDG Dataset Length: 18
# 100107.pt processed.
# Processing 100108.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100108.0 at round                         0.1666666716337204. Skipping the round.
# DTDG Dataset Length: 18
# 100108.pt processed.
# Processing 100109.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100109.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100109.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100109.0 at round                         0.2916666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100109.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100109.0 at round                         0.8333333134651184. Skipping the round.
# DTDG Dataset Length: 17
# 100109.pt processed.
# Processing 100110.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100110.0 at round                         0.0416666679084301. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100110.0 at round                         0.25. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100110.0 at round                         0.4583333432674408. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100110.0 at round                         0.75. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100110.0 at round                         0.875. Skipping the round.
# DTDG Dataset Length: 19
# 100110.pt processed.
# Processing 100111.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.0833333358168602. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.375. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.4166666567325592. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.5416666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.6666666865348816. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100111.0 at round                         0.7083333134651184. Skipping the round.
# DTDG Dataset Length: 9
# 100111.pt processed.
# Processing 100112.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100112.0 at round                         0.1666666716337204. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100112.0 at round                         0.625. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100112.0 at round                         0.7083333134651184. Skipping the round.
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100112.0 at round                         0.75. Skipping the round.
# DTDG Dataset Length: 15
# 100112.pt processed.
# Processing 100113.pt...
# Error:Error: There are missing ticks in the graph sequence. The error occured while parsing match 100113.0 at round                         0.5. Skipping the round.
# DTDG Dataset Length: 20
# 100113.pt processed.

# %%
print(overall_length)
# Out:
# 98098

# %% [markdown]
# # Create temporal dataset with varied length dyxnamic graphs

# %%
train_data = torch.load(PATH_TEMP_GRAPH_DATA_R + 'train.pt', weights_only=False)
random.shuffle(train_data)
print('Train data length:', len(train_data))
# Out:
# Train data length: 1490

# %%
short_train_data = train_data[:750]

# %%
torch.save(short_train_data, DATA_PATH + '/train_r.pt')

# %% [markdown]
# # Test

# %%
test_data = torch.load(DATA_PATH + '100000.pt', weights_only=False)

# %%
thgs = TemporalHeteroGraphSnapshot()
dyn_graphs = thgs.process_match(test_data, interval=20, shifted_intervals=True)
