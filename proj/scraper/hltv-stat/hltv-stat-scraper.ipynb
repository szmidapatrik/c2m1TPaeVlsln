# %% [markdown]
# ## HLTV stat scrape
# ### Get hltv links to player profiles
# ### Scrape stats

# %%
from selenium.webdriver.common.by import By
from selenium import webdriver
from time import sleep
import random
import csv


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------



def get_player_profile_links(url):
    
    browser = webdriver.Firefox()

    browser.get(url)
    sleep(random.uniform(2, 3))
    allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
    allowCookies.click()
    sleep(2)

    player_url = []
    
    players = browser.find_elements(By.CSS_SELECTOR, 'table.stats-table tbody tr')
    for player in players:
        link = player.find_element(By.TAG_NAME, 'a').get_attribute('href')
        player_url.append(link)

    browser.quit()
    
    return player_url


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_link_and_decline_cookies(url):
    
    browser = webdriver.Firefox()
    
    sleep(0.2)
    browser.get(url)
    sleep(3.2)
    
    allowCookies = browser.find_element(By.ID, 'CybotCookiebotDialogBodyLevelButtonLevelOptinAllowAll')
    sleep(random.uniform(0.4, 1.2))
    allowCookies.click()
    
    return browser


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_overview_stats(url, stats):
    
    browser = get_link_and_decline_cookies(url)
    
    try:
        # Highlighted stats
        stats['player_name'] = browser.find_element(By.CSS_SELECTOR, 'h1.summaryNickname').text
        stats['rating_2.0'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[0].text
        stats['DPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[1].text
        stats['KAST'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[2].text[:-1]
        stats['Impact'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[3].text
        stats['ADR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[4].text
        stats['KPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.summaryStatBreakdownDataValue')[5].text
        
        # Other stats
        stats['total_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[0].text.replace('Total kills\n', '')
        stats['HS%'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[1].text.replace('Headshot %\n', '')[:-1]
        stats['total_deaths'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[2].text.replace('Total deaths\n', '')
        stats['KD_ratio'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[3].text.replace('K/D Ratio\n', '')
        stats['dmgPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[4].text.replace('Damage / Round\n', '')
        stats['grenade_dmgPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[5].text.replace('Grenade dmg / Round\n', '')
        stats['maps_played'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[6].text.replace('Maps played\n', '')
        stats['rounds_played'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[7].text.replace('Rounds played\n', '')
        stats['KPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[8].text.replace('Kills / round\n', '')
        stats['APR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[9].text.replace('Assists / round\n', '')
        stats['saved_by_teammatePR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[11].text.replace('Saved by teammate / round\n', '')
        stats['saved_teammatesPR'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[12].text.replace('Saved teammates / round\n', '')
        
        browser.quit()
        return stats
    except:
        browser.quit()
        raise Exception("error while scraping overview stats")


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_individual_stats(url, stats):
    
    url_individual = url.replace('/players/', '/players/individual/')
    browser = get_link_and_decline_cookies(url_individual)
    try:
        stats['rounds_with_kils'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[4].text.replace('Rounds with kills\n', '')
        stats['KD_diff'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[5].text.replace('Kill - Death difference\n', '')
        
        stats['total_opening_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[6].text.replace('Total opening kills\n', '')
        stats['total_opening_deaths'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[7].text.replace('Total opening deaths\n', '')
        stats['opening_kill_ratio'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[8].text.replace('Opening kill ratio\n', '')
        stats['opening_kill_rating'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[9].text.replace('Opening kill rating\n', '')
        stats['team_W%_after_opening'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[10].text[:-1].replace('Team win percent after first kill\n', '')
        stats['opening_kill_in_W_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[11].text[:-1].replace('First kill in won rounds\n', '')
        
        stats['0_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[12].text.replace('0 kill rounds\n', '')
        stats['1_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[13].text.replace('1 kill rounds\n', '')
        stats['2_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[14].text.replace('2 kill rounds\n', '')
        stats['3_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[15].text.replace('3 kill rounds\n', '')
        stats['4_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[16].text.replace('4 kill rounds\n', '')
        stats['5_kill_rounds'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[17].text.replace('5 kill rounds\n', '')
        
        stats['rifle_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[18].text.replace('Rifle kills\n', '')
        stats['sniper_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[19].text.replace('Sniper kills\n', '')
        stats['smg_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[20].text.replace('SMG kills\n', '')
        stats['pistol_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[21].text.replace('Pistol kills\n', '')
        stats['grenade_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[22].text.replace('Grenade\n', '')
        stats['other_kills'] = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')[23].text.replace('Other\n', '')
        
        browser.quit()
        return stats
    except:
        browser.quit()
        raise Exception("error while scraping individual stats")


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_match_stats(url, stats):
    
    url_match = url.replace('/players/', '/players/matches/')
    browser = get_link_and_decline_cookies(url_match)
    try:
        stats['maps_W%'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[1].text[:-1]
        stats['rating_2.0_1+'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[2].text[:-1]
        stats['rating_2.0_1+_streak'] = browser.find_elements(By.CSS_SELECTOR, 'div.value')[3].text
            
        browser.quit()
        return stats
    except:
        browser.quit()
        raise Exception("error while scraping match stats")


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_rating_1_0_table(url, stats):
    
    url_rating = url.replace('/players/', '/players/career/')
    browser = get_link_and_decline_cookies(url_rating)
    try:
        year = browser.find_elements(By.TAG_NAME, 'tr')
        rating_one_stats = {}
        for item in year:
            
            if (item.text.startswith('Past 3 months') or item.text.startswith('Period')):
                continue
            
            values = item.find_elements(By.TAG_NAME, 'td')
            
            if (len(values) != 5):
                    continue
            
            rating_one_stats['rating_1.0_all_' + values[0].text] = values[1].text
            rating_one_stats['rating_1.0_online_' + values[0].text] = values[2].text
            rating_one_stats['rating_1.0_lan_' + values[0].text] = values[3].text
            rating_one_stats['rating_1.0_major_' + values[0].text] = values[4].text
            
            if item.text.startswith('Career'):
                stats['rating_1.0_all_' + values[0].text] = values[1].text
                stats['rating_1.0_online_' + values[0].text] = values[2].text
                stats['rating_1.0_lan_' + values[0].text] = values[3].text
                stats['rating_1.0_major_' + values[0].text] = values[4].text
        
        stats['rating_1.0_data'] = rating_one_stats
        browser.quit()
        return stats
    except:
        browser.quit()
        raise Exception("error while rating 1.0 match stats")

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_weapon_stats(url, stats):
    
    url_weapon = url.replace('/players/', '/players/weapon/')
    browser = get_link_and_decline_cookies(url_weapon)
    try:
        weapon_stats = {}
        weapons = browser.find_elements(By.CSS_SELECTOR, 'div.stats-row')
        for weapon in weapons:
            weapon_name = weapon.text.split('\n')[0].split(' ')[1]
            weapon_stats['kills_' + weapon_name] = weapon.text.split('\n')[1]    
        stats['weapon_data'] = weapon_stats
        
        browser.quit()
        return stats
    except:
        browser.quit()
        raise Exception("error while scraping weapon stats")


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def get_clutch_stats(url, stats):
    
    url_clutch_type_list = ['1on1', '1on2', '1on3', '1on4', '1on5']
    url_clutch = url.replace('/players/', '/players/clutches/')
    url_clutch_array = url_clutch.split('/')
    
    try:
        for clutch_type in url_clutch_type_list:
            
            url_XonX = url_clutch_array.copy()
            url_XonX.insert(7, clutch_type)
            url_clutch = '/'.join(url_XonX)
            browser = get_link_and_decline_cookies(url_clutch)
            
            clutches = browser.find_elements(By.CSS_SELECTOR, 'div.value')
            stats['clutches_won_' + clutch_type] = clutches[0].text
            if clutch_type == '1on1':
                stats['clutches_lost_' + clutch_type] = clutches[1].text 
            
            
            browser.quit()
        
        return stats
    except:
        browser.quit()
        raise Exception("error while scraping clutch stats")


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def create_file(stats, file_name):
    file_path = '../../data/player-stats/scraped-in-2024/{}'.format(file_name)
    with open(file_path, 'w+', newline='') as f:
        writer = csv.writer(f)
        columns = []
        for x in stats:
            columns.append(x)
        writer.writerow(columns)


# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def write_to_csv(stats, file_name):
    file_path = '../../data/player-stats/scraped-in-2024/{}'.format(file_name)
    with open(file_path, 'a', newline='') as f:
        writer = csv.writer(f)
        values = []
        for x in stats:
            values.append(stats[x])
        writer.writerow(values)
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------


def write_url_done(url, file_name):
        
    # Save parsed demo to list
    f = open('./' + file_name, 'a+')
    f.write("%s\n" % url)
    f.close()
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

 
def handle_scrape_error(link_with_error):
    f = open('./errors.txt', 'a+')
    f.write('Error while scraping {}, skipping file\n'.format(link_with_error))
    f.close()
        

# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------

 
def get_player_stats(url, txt_file_name, csv_file_name, year):

    players = get_player_profile_links(url)
    
    for idx, url_player in enumerate(players):

        url_player = url_player.split('?')[0] + "?startDate={}-01-01&endDate={}-12-31".format(year, year)

        # Check wether the demo is alreay parsed
        txt_file_path = './{}'.format(txt_file_name)
        with open(txt_file_path) as f:
            lines = f.read().splitlines()
            if url_player in lines:
                continue
            
        print(url_player)
        
        try:
            stats = get_overview_stats(url_player, {})
            stats = get_individual_stats(url_player, stats)
            stats = get_match_stats(url_player, stats)
            stats = get_rating_1_0_table(url_player, stats)
            stats = get_weapon_stats(url_player, stats)
            stats = get_clutch_stats(url_player, stats)
            
            # if idx == 0:
            #     create_file(stats, csv_file_name)
            write_to_csv(stats, csv_file_name)
        except:
            handle_scrape_error(url_player)
        write_url_done(url_player, txt_file_name)

# %%
# Inferno stats
get_player_stats('https://www.hltv.org/stats/players?startDate=2012-01-01&endDate=2022-01-01&maps=de_inferno&rankingFilter=All')

# %%
# All player stats
SAVE_TXT = 'url_done_2022.txt'
SAVE_CSV = 'player_stats_2022.csv'
get_player_stats('https://www.hltv.org/stats/players?startDate=all&endDate=2023-01-01', SAVE_TXT, SAVE_CSV, 2022)
# Out:
# https://www.hltv.org/stats/players/169/nak?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9081/s0tf1k?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/12016/svyat?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/4218/dav?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8837/akez?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/14010/zmb?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9736/ncl?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/14380/patrick?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/3252/legija?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/21012/ro1f?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/7796/waylander?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/19617/amster?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/4829/mynio?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/7537/xarte?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/10114/bona?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/7821/saw?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/14202/coolio?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/7218/krystal?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/429/karrigan?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9348/crush?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/18875/ricioli?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9295/sycrone?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8294/balblna?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/5327/nkl?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/499/hooch?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/11110/golden?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/15778/sener1?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/6451/fns?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/13250/ben1337?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/19065/shine?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/17390/adk?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/16563/psycho?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/15120/jinkz?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9017/mainline?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/41/pronax?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/18219/adam9130?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9882/polen?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8983/mightymax?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/1206/btn?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/15818/k1-fida?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/16731/iceberg?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/20122/freeze?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8504/lex?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/10993/torben?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8047/lambert?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9798/lunatic?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/1916/seangres?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8521/daps?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8212/scrunk?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/19509/dav1g?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/15726/nawrot?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/921/berry?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/13718/birdfromsky?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/9350/def?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/12572/djl?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8600/advent?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/20593/airax?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/10096/hooxi?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/136/gob-b?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8708/slemmy?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/13779/pashanoj?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/17215/bobz?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/472/b1ad3?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/8422/netrick?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/7415/hunden?startDate=2022-01-01&endDate=2022-12-31
# https://www.hltv.org/stats/players/10827/prt?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7965/larsen?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8327/furlan?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7805/rush?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17039/deco?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/17305/finigan?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7169/rpk?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/13170/kwezz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/2898/raalz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12102/djay?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/14055/propleh?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/7412/gla1ve?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10784/rusty?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10697/blocker?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/12113/jonji?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9916/mono?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/20309/bnox?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19677/kyxsan?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/19575/x5g7v?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/8368/jmqa?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/15901/enzo?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/10192/destroyer?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/21142/masked?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/3886/seb?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/9482/nekiz?startDate=2021-01-01&endDate=2021-12-31
# https://www.hltv.org/stats/players/