# %% [markdown]
# ## Data parse

# %% [markdown]
# ### Parse

# %%
from awpy import DemoParser
import pandas as pd

# demo_parser = DemoParser(demofile='./demo-parse/demo/g2-vs-liquid-m2-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
demo_parser = DemoParser(demofile='./demo-parse/demo/astralis-vs-faze-m2-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
data = demo_parser.parse(return_type='df')
# demo_parser = DemoParser(demofile='./demo-parse/demo/heroic-vs-natus-vincere-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# demo_parser = DemoParser(demofile='./demo-parse/demo/mouz-vs-vitality-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# data2 = demo_parser.parse(return_type='df')
# # demo_parser = DemoParser(demofile='./demo-parse/demo/natus-vincere-vs-outsiders-m2-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# demo_parser = DemoParser(demofile='./demo-parse/demo/natus-vincere-vs-faze-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# data3 = demo_parser.parse(return_type='df')
# # demo_parser = DemoParser(demofile='./demo-parse/demo/g2-vs-big-m2-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# demo_parser = DemoParser(demofile='./demo-parse/demo/natus-vincere-vs-mouz-m3-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# data4 = demo_parser.parse(return_type='df')
# # demo_parser = DemoParser(demofile='./demo-parse/demo/vitality-vs-ninjas-in-pyjamas-m2-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# demo_parser = DemoParser(demofile='./demo-parse/demo/natus-vincere-vs-movistar-riders-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# data5 = demo_parser.parse(return_type='df')
# demo_parser = DemoParser(demofile='./demo-parse/demo/og-vs-mouz-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# demo_parser = DemoParser(demofile='./demo-parse/demo/og-vs-mouz-m1-inferno.dem', demo_id='katowice2023_g2-vs-liquid-m2-inferno', parse_rate=8, outpath='./demo-parse/parse')
# data6 = demo_parser.parse(return_type='df')
# Out:
# A parse rate lower than 64 may be slow depending on the tickrate of the demo, which is usually 64 for MM and 128 for pro demos.
# go: downloading github.com/markus-wa/demoinfocs-golang/v3 v3.3.0
# go: downloading github.com/golang/geo v0.0.0-20210211234256-740aa86cb551
# go: downloading google.golang.org/protobuf v1.30.0
# go: downloading github.com/oklog/ulid/v2 v2.1.0
# go: downloading github.com/markus-wa/go-unassert v0.1.3
# go: downloading github.com/pkg/errors v0.9.1
# go: downloading github.com/markus-wa/quickhull-go/v2 v2.2.0
# go: downloading github.com/markus-wa/godispatch v1.4.1
# go: downloading github.com/markus-wa/ice-cipher-go v0.0.0-20220823210642-1fcccd18c6c1
# go: downloading github.com/markus-wa/gobitread v0.2.3

# %%
data['playerFrames'].to_csv("./demo-parse/parse/player_frames/katowice2023_astralis-vs-faze-m2-inferno.csv")
data2['playerFrames'].to_csv("./demo-parse/parse/player_frames/katowice2023_mouz-vs-vitality-m1-inferno.csv")
data3['playerFrames'].to_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-faze-m1-inferno.csv")
data4['playerFrames'].to_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-mouz-m3-inferno.csv")
data5['playerFrames'].to_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-movistar-riders-m1-inferno.csv")

# %% [markdown]
# ### Read

# %%
import pandas as pd

data = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_faze-vs-fnatic-m2-inferno.csv")
data2 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-big-m2-inferno.csv")
data3 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-faze-m1-inferno.csv")
data4 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-liquid-m2-inferno.csv")
data5 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_heroic-vs-natus-vincere-m1-inferno.csv")
data6 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_heroic-vs-og-m3-inferno.csv")
# data7 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-outsiders-m2-inferno.csv")
# data8 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_og-vs-mouz-m1-inferno.csv")
# data9 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_vitality-vs-gambit-m2-inferno.csv")
# data10 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_vitality-vs-ninjas-in-pyjamas-m2-inferno.csv")
# data11 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_astralis-vs-faze-m2-inferno.csv")
# data12 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_mouz-vs-vitality-m1-inferno.csv")
# data13 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-faze-m1-inferno.csv")
# data14 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-mouz-m3-inferno.csv")
# data15 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_natus-vincere-vs-movistar-riders-m1-inferno.csv")

# %%
import matplotlib.pyplot as plt

pts1 = data[['x','y','z']].copy()
pts2 = data2[['x','y','z']].copy()
pts3 = data3[['x','y','z']].copy()
pts4 = data4[['x','y','z']].copy()
pts5 = data5[['x','y','z']].copy()
pts6 = data6[['x','y','z']].copy()
# pts7 = data7[['x','y','z']].copy()
# pts8 = data8[['x','y','z']].copy()
# pts9 = data9[['x','y','z']].copy()
# pts10 = data10[['x','y','z']].copy()
# pts11 = data11[['x','y','z']].copy()
# pts12 = data12[['x','y','z']].copy()
# pts13 = data13[['x','y','z']].copy()
# pts14 = data14[['x','y','z']].copy()
# pts15 = data15[['x','y','z']].copy()
pts = pd.concat([pts1, pts2, pts3, pts4, pts5, pts6, 
                 # pts7, pts8, pts9, pts10, pts11, pts12, pts13, pts14, pts15
                 ])
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=0.1)

# %%
import numpy as np

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=0.1)
ax.set_xlim(-10,10)
ax.set_ylim(1390,1410)

circle = plt.Circle((0 , 1400), 5, color='r', alpha=0.2)

ax.scatter(0,1400,c="red", s=3, zorder = 2)
ax.add_patch(circle)

pts['dist'] = (pts['x'] ** 2 + (pts['y'] - 1400) ** 2 <= np.sqrt(25*25))
print(pts['dist'].loc[pts['dist'] == True].sum())
ax.scatter(pts.loc[pts['dist'] == True]['x'],  pts.loc[pts['dist'] == True]['y'], c="purple", s=0.25, zorder = 1)
# Out:
# 1105

# %% [markdown]
# ## Graph-auto

# %% [markdown]
# ### Create graph

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_faze-vs-fnatic-m2-inferno.csv")
data2 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-big-m2-inferno.csv")
data3 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-faze-m1-inferno.csv")
data4 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_g2-vs-liquid-m2-inferno.csv")
data5 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_heroic-vs-natus-vincere-m1-inferno.csv")
data6 = pd.read_csv("./demo-parse/parse/player_frames/katowice2023_heroic-vs-og-m3-inferno.csv")


pts1 = data[['x','y','z']].copy()
pts2 = data2[['x','y','z']].copy()
pts3 = data3[['x','y','z']].copy()
pts4 = data4[['x','y','z']].copy()
pts5 = data5[['x','y','z']].copy()
pts6 = data6[['x','y','z']].copy()

pts = pd.concat([pts1, pts2, pts3, pts4, pts5, pts6])
pts['numpts'] = 0

pts
# Out:
#                   x            y           z  numpts
# 0       2292.052002  2027.916138  128.031250       0
# 1       2363.020996  1985.858521  128.031250       0
# 2       2367.102783  2072.798340  128.031250       0
# 3       2469.656494  2094.067139  132.031250       0
# 4       2449.023926  2010.025635  128.031250       0
# ...             ...          ...         ...     ...
# 466965  2198.870605   -15.154139  128.115677       0
# 466966  2072.250488  -216.316666  256.031250       0
# 466967   527.585632  1951.626221  129.990936       0
# 466968  2074.388428  -290.373871  256.031250       0
# 466969  1919.467407  -191.745758  256.031250       0
#
# [2616885 rows x 4 columns]

# %%
from scipy.spatial.distance import cdist
import numpy as np

x = np.linspace(-2000,3000, 60)
y = np.linspace(-1000,4000, 60)

grid = np.column_stack((np.repeat(x, len(y)), np.tile(y, len(x))))

dens = []

# Density
for x_axis in range(-2000,3000,1000):
    for y_axis in range(-1000,4000,1000):
        temp_dens = pts.loc[(pts['x'] >= x_axis) & (pts['x'] < x_axis + 1000) & (pts['y'] >= y_axis) & (pts['y'] < y_axis + 1000)].shape[0]
        dens.append([x_axis, y_axis, temp_dens])

for d in dens:
    pts.loc[(pts['x'] >= d[0]) & (pts['x'] < d[0] + 1000) & (pts['y'] >= d[1]) & (pts['y'] < d[1] + 1000), 'numpts'] = d[2]

pts['dens'] = pts['numpts'] / len(pts)

bars = pts[['numpts', 'dens']].drop_duplicates()
bars['numpts'] = bars['numpts'].astype(str)
plt.bar(bars['numpts'], bars['dens'])

pts_copy = pts.copy()

pts
# Out:
#                   x            y           z  numpts      dens
# 0       2292.052002  2027.916138  128.031250   46819  0.017891
# 1       2363.020996  1985.858521  128.031250   78148  0.029863
# 2       2367.102783  2072.798340  128.031250   46819  0.017891
# 3       2469.656494  2094.067139  132.031250   46819  0.017891
# 4       2449.023926  2010.025635  128.031250   46819  0.017891
# ...             ...          ...         ...     ...       ...
# 466965  2198.870605   -15.154139  128.115677  154396  0.059000
# 466966  2072.250488  -216.316666  256.031250  154396  0.059000
# 466967   527.585632  1951.626221  129.990936  303146  0.115842
# 466968  2074.388428  -290.373871  256.031250  154396  0.059000
# 466969  1919.467407  -191.745758  256.031250  199340  0.076175
#
# [2616885 rows x 5 columns]

# %%
fig, ax = plt.subplots(1,2,figsize=(22,10))


# First plot
ax[0].scatter(pts['x'], pts['y'], s=1, c='darkslateblue', alpha=pts['dens'] / 3)
ax[0].scatter(grid[:,0], grid[:,1], s=0.1, c='black')
for y_l in range(-2000,4000,1000):
    ax[0].plot([y_l,y_l], [-1000, 4000], c="grey", linewidth=0.5)
for x_l in range(-1000,5000,1000):
    ax[0].plot([-2000, 3000], [x_l,x_l], c="grey", linewidth=0.5)
# Manually selected squares
ax[0].fill_between([-2000, -1000], 0, 1000, color='lightblue', alpha=0.5)
ax[0].fill_between([-1000, 0], -1000, 0, color='lightblue', alpha=0.5)
ax[0].fill_between([0, 1000], -1000, 0, color='lightblue', alpha=0.5)
ax[0].fill_between([2000, 3000], 2000, 3000, color='lightblue', alpha=0.5)



ax[1].scatter(pts['x'], pts['y'], s=1, c='darkslateblue', alpha=1)
ax[1].scatter(grid[:,0], grid[:,1], s=0.1, c='black')
for y_l in range(-2000,4000,1000):
    ax[1].plot([y_l,y_l], [-1000, 4000], c="grey", linewidth=0.5)
for x_l in range(-1000,5000,1000):
    ax[1].plot([-2000, 3000], [x_l,x_l], c="grey", linewidth=0.5)

# %%
x_sparse = np.linspace(-2000,3000, 30)
y_sparse = np.linspace(-1000,4000, 30)

grid_sparse = np.column_stack((np.repeat(x_sparse, len(y_sparse)), np.tile(y_sparse, len(x_sparse))))

# Function to calculate points inside circle
def count_points_in_circle(center, radius, points):
    distances = np.sqrt((points.iloc[:,0] - center[0]) ** 2 + (points.iloc[:,1] - center[1]) ** 2)
    points_inside_circle = np.sum(distances <= radius)
    return points_inside_circle

# Szűrés a grid pontokra
filtered_grid_points = []

for grid_point in grid_sparse:
    points_inside = count_points_in_circle(grid_point, 30, pts[['x', 'y']])
    if points_inside >= 5:
        filtered_grid_points.append(grid_point)

filtered_grid_points = np.array(filtered_grid_points)

graph_sparse = pd.DataFrame(filtered_grid_points, columns = ['gX', 'gY'])
graph_sparse.to_csv('./graph-models/models/nodes_v0.2.csv', index=False)

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=1, c='darkslateblue', alpha=1)
ax.scatter(graph_sparse['gX'], graph_sparse['gY'], s=0.1, c='black')

# %%
# Spares grid
sprs1 = graph_sparse.loc[(graph_sparse['gX'] >= -2000) & (graph_sparse['gX'] < -1000) & (graph_sparse['gY'] >= 0) & (graph_sparse['gY'] < 1000)]
sprs2 = graph_sparse.loc[(graph_sparse['gX'] >= -1000) & (graph_sparse['gX'] <  1000) & (graph_sparse['gY'] >= -1000) & (graph_sparse['gY'] < 0)]
sprs3 = graph_sparse.loc[(graph_sparse['gX'] >=  2000) & (graph_sparse['gX'] <  3000) & (graph_sparse['gY'] >= 2000) & (graph_sparse['gY'] < 3000)]
sprs = pd.concat([sprs1, sprs2, sprs3])

# Dense grid
dense = pd.DataFrame(grid, columns = ['gX', 'gY'])
dense = dense.drop(dense.loc[(dense['gX'] >= -2000) & (dense['gX'] < -1000) & (dense['gY'] >= 0) & (dense['gY'] < 1000)].index)
dense = dense.drop(dense.loc[(dense['gX'] >= -1000) & (dense['gX'] <  1000) & (dense['gY'] >= -1000) & (dense['gY'] < 0)].index)
dense = dense.drop(dense.loc[(dense['gX'] >=  2000) & (dense['gX'] <  3000) & (dense['gY'] >= 2000) & (dense['gY'] < 3000)].index)

# Graph
graph_diffdens = pd.concat([sprs, dense])

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=1, c='darkslateblue', alpha=1)
ax.scatter(graph_diffdens['gX'], graph_diffdens['gY'], s=0.1, c='black')
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %% [markdown]
# ### Graph points plot

# %%
graph = pd.read_csv('./graph-models/beta_v1.csv')

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=0.5)
ax.scatter(graph.iloc[:,0], graph.iloc[:,1],s=3,c="black")

# %% [markdown]
# ### Graph edges

# %%
import pandas as pd
import numpy as np

graph = pd.read_csv('./graph-models/beta_v1.csv')
graph['idx'] = graph.index

edges = np.column_stack((np.repeat(graph['idx'].to_numpy(), len(graph['idx'].to_numpy())), np.tile(graph['idx'].to_numpy(), len(graph['idx'].to_numpy()))))

edge = pd.DataFrame(edges, columns = ['source', 'target'])
edge = edge.merge(graph.rename(columns = {'gX':'sourceX', 'gY': 'sourceY', 'idx': 'sourceIdx'}), left_on='source', right_on='sourceIdx')
edge = edge.merge(graph.rename(columns = {'gX':'targetX', 'gY': 'targetY', 'idx': 'targetIdx'}), left_on='target', right_on='targetIdx')
edge['neighbour'] = np.sqrt((edge['sourceX'] - edge['targetX']) ** 2 + (edge['sourceY'] - edge['targetY']) ** 2) <= 85
edge.drop(columns=['source', 'target'], inplace=True)
edge = edge.loc[edge['neighbour'] == True]

edge.to_csv('./graph-models/beta_v1_edges.csv', index=False)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(pts['x'], pts['y'], s=0.5)
ax.scatter(graph.iloc[:,0], graph.iloc[:,1],s=3,c="black")
ax.plot(edge[['sourceX', 'targetX']].to_numpy().T, edge[['sourceY', 'targetY']].to_numpy().T, c="black", linewidth=0.5)
# Out:
# ...
#  ...]

# %% [markdown]
# ### Beta

# %%
import matplotlib.pyplot as plt
import pandas as pd

graph = pd.read_csv('./graph-models/beta_v1.csv')
edge = pd.read_csv('./graph-models/beta_v1_edges.csv')

fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(graph.iloc[:,0], graph.iloc[:,1],s=3,c="black")
ax.plot(edge[['sourceX', 'targetX']].to_numpy().T, edge[['sourceY', 'targetY']].to_numpy().T, c="black", linewidth=0.5)
# Out:
# ...
#  ...]

# %%
graph['idx'] = graph.index
graph.to_csv('./graph-models/beta_v2.csv', index=False)
edge[['sourceIdx', 'targetIdx']].to_csv('./graph-models/beta_v2_edges.csv', index=False)

# %% [markdown]
# ## Graph manual

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(10,10))
plt.scatter(pts['x'], pts['y'],s=1)
