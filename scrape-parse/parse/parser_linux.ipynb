# %% [markdown]
# ## First

# %% [markdown]
# ### Get all demo files in all folders of a given year

# %%
import pandas as pd
import os

# Get all demo files of the given year's folder
def get_demos(folderPath):
    folderMatchs = os.listdir(folderPath)
    file = open(folderPath + 'parsedDemos.txt', 'a+')
    file.close()
    folderDemo = []
    for folder in folderMatchs:
        matches = os.listdir(os.path.join(folderPath, folder))
        for demo in matches:
            folderDemo.append([folder, demo[:-4], os.path.join(folderPath, folder, demo)])
    return pd.DataFrame(folderDemo, columns=['tournament', 'match', 'path']).sort_values(by=['tournament', 'match'])

# %% [markdown]
# ### Parse demos

# %%
import numpy as np
import pandas as pd
import os
from awpy import DemoParser

# Parse demos
def parse(folderPath):

    # Get demo files
    demos = get_demos(folderPath)
    demo_list = demos.iloc[:,2].to_numpy()
    year = folderPath.split("/")[-1]

    # Iterate and parse demos
    for demo in demo_list:
        
        # path strings
        folder = demo.split('/')[-2]
        demoname = demo.split('/')[-1]

        print(demo)

        # Check wether the demo is alreay parsed
        with open(r'/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/parse/' + year + '.txt') as f:
            lines = f.read().splitlines()
            if demo in lines:
                continue

        # Create the datasets in which the data from the matches will be saved
        rounds = pd.DataFrame()
        kills = pd.DataFrame()
        damages = pd.DataFrame()
        grenades = pd.DataFrame()
        flashes = pd.DataFrame()
        weaponFires = pd.DataFrame()
        bombEvents = pd.DataFrame()
        frames = pd.DataFrame()
        playerFrames = pd.DataFrame()

        # Parse demo
        match_id = demo

        demo_parser = DemoParser(demofile='../demo/matches/2023/' + folder + '/' + demoname, demo_id=match_id, parse_rate=16, outpath=r'/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/parse/2023/demo_source')
        data = demo_parser.parse(return_type='df')
        data['frames']['matchID'] = data['matchID']
        data['frames']['mapName'] = data['mapName']

        # Append the parsed demo's data to padas tables
        rounds = data['rounds']
        kills = data['kills']
        damages = data['damages']
        grenades = data['grenades']
        flashes = data['flashes']
        weaponFires = data['weaponFires']
        bombEvents = data['bombEvents']
        frames = data['frames']
        playerFrames = data['playerFrames']

        # Name of demo file
        demoname = demo.split("/")[-2] + '---' + demo.split("/")[-1]

        # Save csv
        rounds.to_csv('../demo/parse/' + year + '/rounds/' + demoname + '.csv')
        kills.to_csv('../demo/parse/' + year + '/kills/' + demoname + '.csv')
        damages.to_csv('../demo/parse/' + year + '/damages/' + demoname + '.csv')
        grenades.to_csv('../demo/parse/' + year + '/grenades/' + demoname + '.csv')
        flashes.to_csv('../demo/parse/' + year + '/flashes/' + demoname + '.csv')
        weaponFires.to_csv('../demo/parse/' + year + '/weaponFires/' + demoname + '.csv')
        bombEvents.to_csv('../demo/parse/' + year + '/bombEvents/' + demoname + '.csv')
        frames.to_csv('../demo/parse/' + year + '/frames/' + demoname + '.csv')
        playerFrames.to_csv('../demo/parse/' + year + '/playerFrames/' + demoname + '.csv')

        # Save parsed demo to list
        f = open(r'/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/parse/' + year + '.txt', 'a')
        f.write("%s\n" % demo)
        f.close()
        print(demoname + 'completed')

# %%
parse('/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/matches/2023')
# Out:
# A parse rate lower than 64 may be slow depending on the tickrate of the demo, which is usually 64 for MM and 128 for pro demos.
# /media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/matches/2023/blast-premier-fall-groups-2023-astralis-vs-complexity-bo3-rg1q7_uJ_qZs1xTVhaJobF/astralis-vs-complexity-m1-vertigo.dem
# No file produced, error in calling Golang
# []
# JSON path does not exist!
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 parse('/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/matches/2023')
#
# Cell In[8], line 44, in parse(folderPath)
#      41 match_id = demo
#      43 demo_parser = DemoParser(demofile='../demo/matches/2023/' + folder + '/' + demoname, demo_id=match_id, parse_rate=16, outpath=r'/media/szmp/Adat/BME/csgo-gnn/scrape-parse/demo/parse/2023/demo_source')
# ---> 44 data = demo_parser.parse(return_type='df')
#      45 data['frames']['matchID'] = data['matchID']
#      46 data['frames']['mapName'] = data['mapName']
#
# File ~/.local/lib/python3.10/site-packages/awpy/parser/demoparser.py:291, in DemoParser.parse(self, return_type, clean)
#     277 """Wrapper for parse_demo() and read_json(). Use to parse a demo.
#     278
#     279 Args:
#    (...)
#     288     AttributeError: Raises an AttributeError if the .json attribute is None
#     289 """
#     290 self.parse_demo()
# --> 291 self.read_json(json_path=self.outpath + "/" + self.output_file)
#     292 if clean:
#     293     clean_data = self.clean_rounds()
#
# File ~/.local/lib/python3.10/site-packages/awpy/parser/demoparser.py:262, in DemoParser.read_json(self, json_path)
#     260 if not os.path.exists(json_path):
#     261     self.logger.error("JSON path does not exist!")
# --> 262     raise FileNotFoundError("JSON path does not exist!")
#     264 # Read in json to .json attribute
#     265 with open(json_path, encoding="utf8") as f:
#
# FileNotFoundError: JSON path does not exist!

# %% [markdown]
# ## Second

# %%
from awpy.parser import DemoParser
import pandas as pd
import os

# Demo parser
def parse(path):

    for folder in os.listdir(path):
        for demo in os.listdir(path + '/' + folder):
            
            if demo.split('.')[-1] != "dem":
                continue

            # path strings
            year = path.split("/")[-1]

            # Check wether the demo is alreay parsed
            with open('../demo/parse/' + year + '.txt') as f:
                lines = f.read().splitlines()
                if (folder + demo) in lines:
                    continue

            # Create the datasets in which the data from the matches will be saved
            rounds = pd.DataFrame()
            kills = pd.DataFrame()
            damages = pd.DataFrame()
            grenades = pd.DataFrame()
            flashes = pd.DataFrame()
            weaponFires = pd.DataFrame()
            bombEvents = pd.DataFrame()
            frames = pd.DataFrame()
            playerFrames = pd.DataFrame()

            # Parse demo
            match_id = folder + demo

            demo_parser = DemoParser(demofile='../demo/matches/2023/' + folder + '/' + demo, demo_id=match_id, parse_rate=16, outpath='../demo/parse/2023/demo_source')
            data = demo_parser.parse(return_type='df')
            data['frames']['matchID'] = data['matchID']
            data['frames']['mapName'] = data['mapName']

            # Append the parsed demo's data to padas tables
            rounds = data['rounds']
            kills = data['kills']
            damages = data['damages']
            grenades = data['grenades']
            flashes = data['flashes']
            weaponFires = data['weaponFires']
            bombEvents = data['bombEvents']
            frames = data['frames']
            playerFrames = data['playerFrames']

            # Name of demo file
            demoname = folder + demo

            # Save csv
            rounds.to_csv('../demo/parse/' + year + '/rounds/' + demoname + '.csv')
            kills.to_csv('../demo/parse/' + year + '/kills/' + demoname + '.csv')
            damages.to_csv('../demo/parse/' + year + '/damages/' + demoname + '.csv')
            grenades.to_csv('../demo/parse/' + year + '/grenades/' + demoname + '.csv')
            flashes.to_csv('../demo/parse/' + year + '/flashes/' + demoname + '.csv')
            weaponFires.to_csv('../demo/parse/' + year + '/weaponFires/' + demoname + '.csv')
            bombEvents.to_csv('../demo/parse/' + year + '/bombEvents/' + demoname + '.csv')
            frames.to_csv('../demo/parse/' + year + '/frames/' + demoname + '.csv')
            playerFrames.to_csv('../demo/parse/' + year + '/playerFrames/' + demoname + '.csv')

            # Save parsed demo to list
            f = open('../demo/parse/' + year + '.txt', 'a')
            f.write("%s\n" % (folder + demo))
            f.close()
            print(folder + demo)

# %%
path = '../demo/matches/2023'
parse(path)
# Out:
# A parse rate lower than 64 may be slow depending on the tickrate of the demo, which is usually 64 for MM and 128 for pro demos.
# mouz-vs-pain-m1-nuke.dem
# mouz-vs-pain-m2-inferno.dem
# mouz-vs-pain-m3-ancient.dem
# astralis-vs-complexity-m1-vertigo.dem
# astralis-vs-complexity-m2-overpass.dem
# big-vs-astralis-m1-anubis.dem
# big-vs-astralis-m2-ancient.dem
# big-vs-astralis-m3-overpass.dem
# complexity-vs-ninjas-in-pyjamas-m1-mirage.dem
# complexity-vs-ninjas-in-pyjamas-m2-overpass.dem
# complexity-vs-ninjas-in-pyjamas-m3-nuke.dem
# evil-geniuses-vs-g2-m1-inferno.dem
# evil-geniuses-vs-g2-m2-nuke.dem
# evil-geniuses-vs-g2-m3-mirage.dem
# evil-geniuses-vs-ninjas-in-pyjamas-m1-inferno.dem
# evil-geniuses-vs-ninjas-in-pyjamas-m2-vertigo.dem
# faze-vs-g2-m1-nuke.dem
# faze-vs-g2-m2-mirage.dem
# faze-vs-liquid-m1-inferno.dem
# faze-vs-liquid-m2-mirage.dem
# faze-vs-liquid-m3-ancient.dem
# faze-vs-og-m1-inferno.dem
# faze-vs-og-m2-mirage.dem
# g2-vs-liquid-m1-ancient.dem
# g2-vs-liquid-m2-mirage.dem
# g2-vs-liquid-m3-vertigo.dem
# heroic-vs-big-m1-overpass.dem
# g2-vs-faze-m3-mirage.dem
# g2-vs-heroic-m1-inferno.dem
# g2-vs-heroic-m2-ancient.dem
# g2-vs-nouns-inferno.dem
# g2-vs-og-m1-mirage.dem
# g2-vs-og-m2-inferno.dem
# heroic-vs-9z-mirage.dem
# imperial-vs-complexity-m1-vertigo.dem
# imperial-vs-complexity-m2-overpass.dem
# imperial-vs-g2-m1-ancient.dem
# imperial-vs-g2-m2-inferno.dem
# imperial-vs-g2-m3-nuke.dem
# vitality-vs-cloud9-m1-overpass.dem
# vitality-vs-cloud9-m2-anubis.dem
# vitality-vs-faze-m1-anubis.dem
# vitality-vs-faze-m2-mirage.dem
# astralis-vs-ninjas-in-pyjamas-m1-overpass.dem
# astralis-vs-ninjas-in-pyjamas-m2-mirage.dem
# astralis-vs-ninjas-in-pyjamas-m3-ancient.dem
# big-vs-liquid-m1-nuke.dem
# big-vs-liquid-m2-anubis.dem
# big-vs-ninjas-in-pyjamas-m1-mirage.dem
# big-vs-ninjas-in-pyjamas-m2-inferno.dem
# complexity-vs-evil-geniuses-m1-anubis-p1.dem
# complexity-vs-evil-geniuses-m2-inferno.dem
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[44], line 2
#       1 path = '../demo/matches/2023'
# ----> 2 parse(path)
#
# Cell In[43], line 37, in parse(path)
#      34 match_id = folder + demo
#      36 demo_parser = DemoParser(demofile='../demo/matches/2023/' + folder + '/' + demo, demo_id=match_id, parse_rate=16, outpath='../demo/parse/2023/demo_source')
# ---> 37 data = demo_parser.parse(return_type='df')
#      38 data['frames']['matchID'] = data['matchID']
#      39 data['frames']['mapName'] = data['mapName']
#
# File ~/.local/lib/python3.10/site-packages/awpy/parser/demoparser.py:290, in DemoParser.parse(self, return_type, clean)
#     274 def parse(
#     275     self, return_type: str = "json", clean: bool = True
#     276 ) -> Union[Game, dict[str, Any]]:
#     277     """Wrapper for parse_demo() and read_json(). Use to parse a demo.
#     278
#     279     Args:
#    (...)
#     288         AttributeError: Raises an AttributeError if the .json attribute is None
#     289     """
# --> 290     self.parse_demo()
#     291     self.read_json(json_path=self.outpath + "/" + self.output_file)
#     292     if clean:
#
# File ~/.local/lib/python3.10/site-packages/awpy/parser/demoparser.py:237, in DemoParser.parse_demo(self)
#     231     self.parser_cmd.append("--parsechat")
#     232 proc = subprocess.Popen(
#     233     self.parser_cmd,
#     234     stdout=subprocess.PIPE,
#     235     cwd=path,
#     236 )
# --> 237 stdout = proc.stdout.read().splitlines() if proc.stdout is not None else None
#     238 self.output_file = self.demo_id + ".json"
#     239 if os.path.isfile(self.outpath + "/" + self.output_file):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Inferno estimates

# %%
print(('- inferno matches in 2023 = {}, estimated rounds: {}').format(138, 138 * 20))
print(('- inferno matches in 2022 = {}, estimated rounds: {}').format(172, 172 * 20))
# Out:
# - inferno matches in 2023 = 138, estimated rounds: 2760
# - inferno matches in 2022 = 172, estimated rounds: 3440
